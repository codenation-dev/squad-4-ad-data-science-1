# %% [markdown]
# # Final Challenge Code:Nation Data Science
# ***

# %% [markdown]
# # General Basic Analysis
# ***

# %% [markdown]
# > ## Purpose:
# Understand market and portfolio data as well as its characteristics and correlations. In order to extract information relevant to the construction of a recommendation model.

# %% [markdown]
# ***
# # Exploratory Data Analysis

# %% [markdown]
# >## Packages:

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.core.pylabtools import figsize

# %% [markdown]
# ***
# >## Datasets:

# %%
market = pd.read_csv("estaticos_market.csv")
portfolio_1 = pd.read_csv("estaticos_portfolio1.csv")
portfolio_2 = pd.read_csv("estaticos_portfolio2.csv")
portfolio_3 = pd.read_csv("estaticos_portfolio3.csv")

# %% [markdown]
# ***
# > ## Shapes: Rows x Columns

# %%
print("(Rows, Columns) of market dataset:", market.shape)
print("(Rows, Columns) of portfolio 1 dataset:",portfolio_1.shape)
print("(Rows, Columns) of portfolio 2 dataset:",portfolio_2.shape)
print("(Rows, Columns) of portfolio 3 dataset:",portfolio_3.shape)
# Out:
# (Rows, Columns) of market dataset: (462298, 182)
# (Rows, Columns) of portfolio 1 dataset: (555, 182)
# (Rows, Columns) of portfolio 2 dataset: (566, 2)
# (Rows, Columns) of portfolio 3 dataset: (265, 2)

# %% [markdown]
# ***
# > ## Heads View:

# %% [markdown]
# >> ### Market:

# %%
market.head()
# Out:
#    Unnamed: 0                                                 id  fl_matriz  \
# 0           0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1           1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2           2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3           3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4           4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo             setor  \
# 0                         INDUSTRIA DA CONSTRUCAO  CONSTRUÇÃO CIVIL
# 1              SERVICOS DE ALOJAMENTO/ALIMENTACAO           SERVIÇO
# 2               TRANSPORTE, ARMAZENAGEM E CORREIO           SERVIÇO
# 3                               SERVICOS DIVERSOS           SERVIÇO
# 4  SERVICOS PROFISSIONAIS, TECNICOS E CIENTIFICOS           SERVIÇO
#
#    idade_empresa_anos idade_emp_cat  ...  media_meses_servicos  \
# 0           14.457534       10 a 15  ...             43.738462
# 1            1.463014         1 a 5  ...                   NaN
# 2            7.093151        5 a 10  ...                   NaN
# 3            6.512329        5 a 10  ...                   NaN
# 4            3.200000         1 a 5  ...                   NaN
#
#    max_meses_servicos  min_meses_servicos  qt_funcionarios  \
# 0           93.266667           19.166667             26.0
# 1                 NaN                 NaN              NaN
# 2                 NaN                 NaN              NaN
# 3                 NaN                 NaN              NaN
# 4                 NaN                 NaN              NaN
#
#    qt_funcionarios_12meses qt_funcionarios_24meses  tx_crescimento_12meses  \
# 0                     26.0                    27.0                     0.0
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
#
#    tx_crescimento_24meses  tx_rotatividade qt_filiais
# 0               -3.703704              0.0          0
# 1                     NaN              NaN          0
# 2                     NaN              NaN          0
# 3                     NaN              NaN          0
# 4                     NaN              NaN          0
#
# [5 rows x 182 columns]

# %% [markdown]
# ***
# >> ### Portfolio 1:

# %%
portfolio_1.head()
# Out:
#    Unnamed: 0                                                 id  fl_matriz  \
# 0           0  dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1           1  32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2           2  a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3           3  6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4           4  f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 1          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 4  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#               de_ramo     setor  idade_empresa_anos idade_emp_cat  ...  \
# 0  COMERCIO VAREJISTA  COMERCIO            0.646575          <= 1  ...
# 1  COMERCIO VAREJISTA  COMERCIO            6.586301        5 a 10  ...
# 2  COMERCIO VAREJISTA  COMERCIO            8.010959        5 a 10  ...
# 3  COMERCIO VAREJISTA  COMERCIO           20.863014          > 20  ...
# 4  COMERCIO VAREJISTA  COMERCIO           18.726027       15 a 20  ...
#
#    media_meses_servicos  max_meses_servicos  min_meses_servicos  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3                   NaN                 NaN                 NaN
# 4             39.454762                91.2           19.333333
#
#    qt_funcionarios  qt_funcionarios_12meses qt_funcionarios_24meses  \
# 0              NaN                      NaN                     NaN
# 1              0.0                      0.0                     2.0
# 2              NaN                      NaN                     NaN
# 3              NaN                      NaN                     NaN
# 4             14.0                     15.0                    25.0
#
#    tx_crescimento_12meses  tx_crescimento_24meses  tx_rotatividade qt_filiais
# 0                     NaN                     NaN              NaN          0
# 1                     NaN                  -100.0              0.0          4
# 2                     NaN                     NaN              NaN          0
# 3                     NaN                     NaN              NaN          0
# 4               -6.666667                   -44.0              0.0          3
#
# [5 rows x 182 columns]

# %% [markdown]
# ***
# >> ### Portfolio 2:

# %%
portfolio_2.head()
# Out:
#    Unnamed: 0                                                 id
# 0           0  09e95c1a84049001d086470a8f320a19b076f955a89122...
# 1           1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...
# 2           2  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 3           3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...
# 4           4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...

# %% [markdown]
# ***
# >> ### Portfolio 3:

# %%
portfolio_3.head()
# Out:
#    Unnamed: 0                                                 id
# 0           0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...
# 1           1  16843c9ffb920170477118933798510d8d5f00f5c56c12...
# 2           2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...
# 3           3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...
# 4           4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...

# %% [markdown]
# ***
# > ## Exploring the Dataset Market:

# %% [markdown]
# >> ### Data types:

# %%
data_types_market = market.dtypes
data_types_market
# Out:
# Unnamed: 0                                         int64
# id                                                object
# fl_matriz                                           bool
# de_natureza_juridica                              object
# sg_uf                                             object
# natureza_juridica_macro                           object
# de_ramo                                           object
# setor                                             object
# idade_empresa_anos                               float64
# idade_emp_cat                                     object
# fl_me                                               bool
# fl_sa                                               bool
# fl_epp                                              bool
# fl_mei                                              bool
# fl_ltda                                             bool
# dt_situacao                                       object
# fl_st_especial                                      bool
# fl_email                                            bool
# fl_telefone                                         bool
# fl_rm                                             object
# nm_divisao                                        object
# nm_segmento                                       object
# fl_spa                                            object
# fl_antt                                           object
# fl_veiculo                                        object
# vl_total_tancagem                                float64
# vl_total_veiculos_antt                           float64
# vl_total_veiculos_leves                          float64
# vl_total_veiculos_pesados                        float64
# fl_optante_simples                                object
#                                                   ...
# idade_de_34_a_38                                 float64
# idade_de_39_a_43                                 float64
# idade_de_44_a_48                                 float64
# idade_de_49_a_53                                 float64
# idade_de_54_a_58                                 float64
# idade_acima_de_58                                float64
# grau_instrucao_macro_analfabeto                  float64
# grau_instrucao_macro_escolaridade_fundamental    float64
# grau_instrucao_macro_escolaridade_media          float64
# grau_instrucao_macro_escolaridade_superior       float64
# grau_instrucao_macro_desconhecido                float64
# total                                            float64
# meses_ultima_contratacaco                        float64
# qt_admitidos_12meses                             float64
# qt_desligados_12meses                            float64
# qt_desligados                                    float64
# qt_admitidos                                     float64
# media_meses_servicos_all                         float64
# max_meses_servicos_all                           float64
# min_meses_servicos_all                           float64
# media_meses_servicos                             float64
# max_meses_servicos                               float64
# min_meses_servicos                               float64
# qt_funcionarios                                  float64
# qt_funcionarios_12meses                          float64
# qt_funcionarios_24meses                          float64
# tx_crescimento_12meses                           float64
# tx_crescimento_24meses                           float64
# tx_rotatividade                                  float64
# qt_filiais                                         int64
# Length: 182, dtype: object

# %% [markdown]
# ***
# >> ### Number of columns with NA's:

# %%
qt_cols_na_market = len(market.columns[market.isna().any()])
qt_cols_na_market
# Out:
# 163

# %% [markdown]
# ***
# >> ### Number of columns without NA's:

# %%
qt_cols_wtt_na_market = len(market.columns) - qt_cols_na_market
qt_cols_wtt_na_market
# Out:
# 19

# %% [markdown]
# ***
# >>  ### NA's count per column:

# %%
qt_na_per_col_market = market.isna().sum().sort_values(ascending=False)
qt_na_per_col_market
# Out:
# qt_alteracao_socio_180d              462298
# grau_instrucao_macro_desconhecido    462298
# qt_alteracao_socio_90d               462298
# qt_alteracao_socio_365d              462298
# qt_alteracao_socio_total             462298
# coligada_mais_nova_baixada           462162
# coligada_mais_antiga_baixada         462162
# idade_media_coligadas_baixadas       462162
# vl_total_veiculos_antt               462122
# vl_total_tancagem                    462018
# vl_total_veiculos_antt_grupo         461962
# vl_total_tancagem_grupo              460538
# grau_instrucao_macro_analfabeto      460414
# idade_ate_18                         459392
# qt_socios_st_suspensa                459047
# vl_potenc_cons_oleo_gas              458615
# qt_socios_pj_suspensos               457754
# vl_idade_minima_socios_pj            457754
# qt_socios_pj_inaptos                 457754
# vl_idade_maxima_socios_pj            457754
# qt_socios_pj_baixados                457754
# vl_idade_media_socios_pj             457754
# qt_socios_pj_nulos                   457754
# qt_socios_pj_ativos                  457754
# qt_art                               455708
# qt_socios_pep                        455555
# idade_acima_de_58                    451272
# idade_de_54_a_58                     448323
# idade_de_49_a_53                     443261
# min_filiais_coligados                441898
#                                       ...
# fl_antt                                1927
# setor                                  1927
# nm_divisao                             1927
# nm_segmento                            1927
# fl_spa                                 1927
# fl_passivel_iss                        1927
# fl_veiculo                             1927
# vl_total_veiculos_pesados_grupo        1927
# vl_total_veiculos_leves_grupo          1927
# fl_simples_irregular                   1927
# dt_situacao                               6
# idade_emp_cat                             0
# id                                        0
# fl_matriz                                 0
# de_natureza_juridica                      0
# sg_uf                                     0
# natureza_juridica_macro                   0
# de_ramo                                   0
# idade_empresa_anos                        0
# qt_filiais                                0
# fl_me                                     0
# fl_sa                                     0
# fl_epp                                    0
# fl_mei                                    0
# fl_ltda                                   0
# fl_st_especial                            0
# fl_email                                  0
# fl_telefone                               0
# fl_rm                                     0
# Unnamed: 0                                0
# Length: 182, dtype: int64

# %% [markdown]
# ***
# >> ### Dataframe market without columns with NA's:

# %%
market_T1 = market.dropna(axis = 'columns')
market_T1 = market_T1.drop(['Unnamed: 0'], axis = 1) # Delete column'Unnamed: 0'.
market_T1.head()
# Out:
#                                                   id  fl_matriz  \
# 0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo  idade_empresa_anos  \
# 0                         INDUSTRIA DA CONSTRUCAO           14.457534
# 1              SERVICOS DE ALOJAMENTO/ALIMENTACAO            1.463014
# 2               TRANSPORTE, ARMAZENAGEM E CORREIO            7.093151
# 3                               SERVICOS DIVERSOS            6.512329
# 4  SERVICOS PROFISSIONAIS, TECNICOS E CIENTIFICOS            3.200000
#
#   idade_emp_cat  fl_me  fl_sa  fl_epp  fl_mei  fl_ltda  fl_st_especial  \
# 0       10 a 15  False  False   False   False    False           False
# 1         1 a 5  False  False   False    True    False           False
# 2        5 a 10  False  False   False    True    False           False
# 3        5 a 10  False  False   False   False    False           False
# 4         1 a 5  False  False   False   False    False           False
#
#    fl_email  fl_telefone fl_rm  qt_filiais
# 0      True         True   SIM           0
# 1      True         True   SIM           0
# 2     False         True   SIM           0
# 3      True         True   SIM           0
# 4      True         True   SIM           0

# %%
print("After this first handling, the market dimensions (row, column) are:", market_T1.shape)
# Out:
# After this first handling, the market dimensions (row, column) are: (462298, 18)

# %% [markdown]
# ***
# >> ### Unique Values:

# %%
# First an adjustment in the 'idade_empresa_anos' column that floats:
market_T1['idade_empresa_anos'] = market_T1['idade_empresa_anos'].round().astype(int)

qt_val_uni_market_T1 = market_T1.nunique()
data_types_market_T1 = market_T1.dtypes
market_T1_qt_un_tp = pd.concat([qt_val_uni_market_T1, data_types_market_T1], axis = 1).reset_index()
market_T1_qt_un_tp.columns = ['Column', 'Unique_values', 'Tipo']
market_T1_qt_un_tp
# Out:
#                      Column  Unique_values    Tipo
# 0                        id         462298  object
# 1                 fl_matriz              2    bool
# 2      de_natureza_juridica             67  object
# 3                     sg_uf              6  object
# 4   natureza_juridica_macro              7  object
# 5                   de_ramo             33  object
# 6        idade_empresa_anos             71   int64
# 7             idade_emp_cat              6  object
# 8                     fl_me              2    bool
# 9                     fl_sa              2    bool
# 10                   fl_epp              1    bool
# 11                   fl_mei              2    bool
# 12                  fl_ltda              2    bool
# 13           fl_st_especial              2    bool
# 14                 fl_email              2    bool
# 15              fl_telefone              2    bool
# 16                    fl_rm              2  object
# 17               qt_filiais            304   int64

# %% [markdown]
# >> ### Frequency of Unique Values:

# %%
freq_val_uni_market_T1 = market_T1.drop(['id'], axis =1).apply(lambda x: [x.value_counts().to_dict()])
freq_val_uni_market_T1
# Out:
# fl_matriz                                     [{True: 433232, False: 29066}]
# de_natureza_juridica       [{'EMPRESARIO INDIVIDUAL': 295756, 'SOCIEDADE ...
# sg_uf                      [{'MA': 127654, 'RN': 98837, 'AM': 82114, 'PI'...
# natureza_juridica_macro    [{'OUTROS': 320211, 'ENTIDADES EMPRESARIAIS': ...
# de_ramo                    [{'COMERCIO VAREJISTA': 172404, 'SERVICOS DIVE...
# idade_empresa_anos         [{1: 43140, 2: 37293, 3: 36525, 4: 29967, 5: 2...
# idade_emp_cat              [{'1 a 5': 138580, '5 a 10': 116100, '> 20': 7...
# fl_me                                          [{False: 461083, True: 1215}]
# fl_sa                                          [{False: 453866, True: 8432}]
# fl_epp                                                     [{False: 462298}]
# fl_mei                                       [{False: 311398, True: 150900}]
# fl_ltda                                        [{False: 461056, True: 1242}]
# fl_st_especial                                   [{False: 462230, True: 68}]
# fl_email                                     [{False: 256228, True: 206070}]
# fl_telefone                                  [{True: 335468, False: 126830}]
# fl_rm                                       [{'NAO': 236779, 'SIM': 225519}]
# qt_filiais                 [{0: 418043, 1: 19561, 2: 5943, 3: 2884, 4: 17...
# dtype: object

# %% [markdown]
# ***
# >> ## Data Visualization:

# %% [markdown]
# >> ### Graphs:

# %%
sns.set()

# %%
f, axes= plt.subplots(4, 3, figsize=(18, 20))

sns.countplot(data=market_T1, x="fl_matriz", palette = 'gist_gray', order = market_T1['fl_matriz'].value_counts().index, ax=axes[0,0]);
axes[0,0].set_title("fl_matriz")
axes[0,0].set_ylabel("")
axes[0,0].set_xlabel("")

sns.countplot(data=market_T1, x="sg_uf", palette = 'gist_gray', order = market_T1['sg_uf'].value_counts().index, ax=axes[0,1]);
axes[0,1].set_title("sg_uf")
axes[0,1].set_ylabel("")
axes[0,1].set_xlabel("")

sns.countplot(data=market_T1, x="idade_emp_cat", palette = 'gist_gray', order = market_T1['idade_emp_cat'].value_counts().index, ax=axes[0,2]);
axes[0,2].set_title("idade_emp_cat")
axes[0,2].set_ylabel("")
axes[0,2].set_xlabel("")

sns.countplot(data=market_T1, x="fl_me", palette = 'gist_gray', order = market_T1['fl_me'].value_counts().index, ax=axes[1,0]);
axes[1,0].set_title("fl_me")
axes[1,0].set_ylabel("")
axes[1,0].set_xlabel("")

sns.countplot(data=market_T1, x="fl_sa", palette = 'gist_gray', order = market_T1['fl_sa'].value_counts().index, ax=axes[1,1]);
axes[1,1].set_title("fl_sa")
axes[1,1].set_ylabel("")
axes[1,1].set_xlabel("")

sns.countplot(data=market_T1, x="fl_mei", palette = 'gist_gray', order = market_T1['fl_mei'].value_counts().index, ax=axes[1,2]);
axes[1,2].set_title("fl_mei")
axes[1,2].set_ylabel("")
axes[1,2].set_xlabel("")

sns.countplot(data=market_T1, x="fl_ltda", palette = 'gist_gray', order = market_T1['fl_ltda'].value_counts().index, ax=axes[2,0]);
axes[2,0].set_title("fl_ltda")
axes[2,0].set_ylabel("")
axes[2,0].set_xlabel("")

sns.countplot(data=market_T1, x="fl_st_especial", palette = 'gist_gray', order = market_T1['fl_st_especial'].value_counts().index, ax=axes[2,1]);
axes[2,1].set_title("fl_st_especial")
axes[2,1].set_ylabel("")
axes[2,1].set_xlabel("")

sns.countplot(data=market_T1, x="fl_email", palette = 'gist_gray', order = market_T1['fl_email'].value_counts().index, ax=axes[2,2]);
axes[2,2].set_title("fl_email")
axes[2,2].set_ylabel("")
axes[2,2].set_xlabel("")

sns.countplot(data=market_T1, x="fl_telefone", palette = 'gist_gray', order = market_T1['fl_telefone'].value_counts().index, ax=axes[3,0]);
axes[3,0].set_title("fl_telefone")
axes[3,0].set_ylabel("")
axes[3,0].set_xlabel("")

sns.countplot(data=market_T1, x="fl_rm", palette = 'gist_gray', order = market_T1['fl_rm'].value_counts().index, ax=axes[3,1]);
axes[3,1].set_title("fl_rm")
axes[3,1].set_ylabel("")
axes[3,1].set_xlabel("")

sns.countplot(data=market_T1, x="fl_epp", palette = 'gist_gray', order = market_T1['fl_epp'].value_counts().index, ax=axes[3,2]);
axes[3,2].set_title("fl_epp")
axes[3,2].set_ylabel("")
axes[3,2].set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=market_T1, x="de_natureza_juridica", palette = 'gist_gray', order = market_T1['de_natureza_juridica'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_natureza_juridica")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=market_T1, x="natureza_juridica_macro", palette = 'gist_gray', order = market_T1['natureza_juridica_macro'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("natureza_juridica_macro")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=market_T1, x="de_ramo", palette = 'gist_gray', order = market_T1['de_ramo'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_ramo")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=market_T1, x="idade_empresa_anos", palette = 'gist_gray', order = market_T1['idade_empresa_anos'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("idade_empresa_anos")
ax.set_ylabel("")
ax.set_xlabel("")

plt.show()

# %% [markdown]
# ***
# >> ### Correlations:

# %%
# Convert object columns to numeric value
market_T1['de_natureza_juridica'] = pd.factorize(market_T1['de_natureza_juridica'])[0]
market_T1['sg_uf'] = pd.factorize(market_T1['sg_uf'])[0]
market_T1['natureza_juridica_macro'] = pd.factorize(market_T1['natureza_juridica_macro'])[0]
market_T1['de_ramo'] = pd.factorize(market_T1['de_ramo'])[0]
market_T1['idade_emp_cat'] = pd.factorize(market_T1['idade_emp_cat'])[0]
market_T1['fl_rm'] = pd.factorize(market_T1['fl_rm'])[0]

# %%
correlation = market_T1.corr(method="pearson")
correlation
# Out:
#                          fl_matriz  de_natureza_juridica     sg_uf  \
# fl_matriz                 1.000000             -0.139675  0.003383
# de_natureza_juridica     -0.139675              1.000000  0.019214
# sg_uf                     0.003383              0.019214  1.000000
# natureza_juridica_macro   0.172292              0.340687 -0.005030
# de_ramo                  -0.059943              0.021511 -0.001882
# idade_empresa_anos       -0.066308              0.047197  0.037635
# idade_emp_cat            -0.002898              0.019167  0.018726
# fl_me                    -0.000106             -0.000029 -0.007985
# fl_sa                    -0.142037              0.123846 -0.003566
# fl_epp                         NaN                   NaN       NaN
# fl_mei                    0.180082             -0.186859 -0.063092
# fl_ltda                  -0.020816              0.087557 -0.009415
# fl_st_especial            0.003142              0.002509  0.001196
# fl_email                 -0.009068              0.025625 -0.150555
# fl_telefone               0.062251             -0.024119 -0.029513
# fl_rm                     0.002995              0.041568  0.261945
# qt_filiais               -0.236179              0.206322 -0.000338
#
#                          natureza_juridica_macro   de_ramo  \
# fl_matriz                               0.172292 -0.059943
# de_natureza_juridica                    0.340687  0.021511
# sg_uf                                  -0.005030 -0.001882
# natureza_juridica_macro                 1.000000 -0.097815
# de_ramo                                -0.097815  1.000000
# idade_empresa_anos                     -0.033300  0.091900
# idade_emp_cat                           0.040741  0.018000
# fl_me                                  -0.006384  0.005332
# fl_sa                                  -0.038705  0.058151
# fl_epp                                       NaN       NaN
# fl_mei                                  0.113138 -0.113959
# fl_ltda                                -0.074715  0.026222
# fl_st_especial                         -0.003498  0.003715
# fl_email                               -0.050747 -0.005111
# fl_telefone                            -0.041411 -0.047668
# fl_rm                                   0.099733  0.011484
# qt_filiais                             -0.030402  0.007932
#
#                          idade_empresa_anos  idade_emp_cat     fl_me  \
# fl_matriz                         -0.066308      -0.002898 -0.000106
# de_natureza_juridica               0.047197       0.019167 -0.000029
# sg_uf                              0.037635       0.018726 -0.007985
# natureza_juridica_macro           -0.033300       0.040741 -0.006384
# de_ramo                            0.091900       0.018000  0.005332
# idade_empresa_anos                 1.000000       0.326331  0.000961
# idade_emp_cat                      0.326331       1.000000 -0.000897
# fl_me                              0.000961      -0.000897  1.000000
# fl_sa                              0.054700       0.002852 -0.006997
# fl_epp                                  NaN            NaN       NaN
# fl_mei                            -0.485454      -0.103275 -0.035734
# fl_ltda                            0.019890       0.009979  0.267504
# fl_st_especial                     0.025071       0.008232 -0.000623
# fl_email                          -0.357666      -0.116546  0.004880
# fl_telefone                       -0.603360      -0.309735  0.004766
# fl_rm                              0.013730      -0.012217  0.000989
# qt_filiais                         0.057729       0.009109 -0.002891
#
#                             fl_sa  fl_epp    fl_mei   fl_ltda  fl_st_especial  \
# fl_matriz               -0.142037     NaN  0.180082 -0.020816        0.003142
# de_natureza_juridica     0.123846     NaN -0.186859  0.087557        0.002509
# sg_uf                   -0.003566     NaN -0.063092 -0.009415        0.001196
# natureza_juridica_macro -0.038705     NaN  0.113138 -0.074715       -0.003498
# de_ramo                  0.058151     NaN -0.113959  0.026222        0.003715
# idade_empresa_anos       0.054700     NaN -0.485454  0.019890        0.025071
# idade_emp_cat            0.002852     NaN -0.103275  0.009979        0.008232
# fl_me                   -0.006997     NaN -0.035734  0.267504       -0.000623
# fl_sa                    1.000000     NaN -0.094883 -0.006762        0.002346
# fl_epp                        NaN     NaN       NaN       NaN             NaN
# fl_mei                  -0.094883     NaN  1.000000 -0.036041       -0.008443
# fl_ltda                 -0.006762     NaN -0.036041  1.000000        0.020046
# fl_st_especial           0.002346     NaN -0.008443  0.020046        1.000000
# fl_email                -0.016247     NaN  0.169873  0.001629       -0.002982
# fl_telefone             -0.034624     NaN  0.377759 -0.014073       -0.009732
# fl_rm                    0.013625     NaN -0.029613 -0.019239        0.002202
# qt_filiais               0.157601     NaN -0.042687 -0.002886       -0.000698
#
#                          fl_email  fl_telefone     fl_rm  qt_filiais
# fl_matriz               -0.009068     0.062251  0.002995   -0.236179
# de_natureza_juridica     0.025625    -0.024119  0.041568    0.206322
# sg_uf                   -0.150555    -0.029513  0.261945   -0.000338
# natureza_juridica_macro -0.050747    -0.041411  0.099733   -0.030402
# de_ramo                 -0.005111    -0.047668  0.011484    0.007932
# idade_empresa_anos      -0.357666    -0.603360  0.013730    0.057729
# idade_emp_cat           -0.116546    -0.309735 -0.012217    0.009109
# fl_me                    0.004880     0.004766  0.000989   -0.002891
# fl_sa                   -0.016247    -0.034624  0.013625    0.157601
# fl_epp                        NaN          NaN       NaN         NaN
# fl_mei                   0.169873     0.377759 -0.029613   -0.042687
# fl_ltda                  0.001629    -0.014073 -0.019239   -0.002886
# fl_st_especial          -0.002982    -0.009732  0.002202   -0.000698
# fl_email                 1.000000     0.361211 -0.112378    0.008246
# fl_telefone              0.361211     1.000000 -0.019218    0.003295
# fl_rm                   -0.112378    -0.019218  1.000000    0.013913
# qt_filiais               0.008246     0.003295  0.013913    1.000000

# %%
cor_market_T1 = market_T1.drop(['fl_epp'], axis = 1)
correlation = cor_market_T1.corr(method="pearson")
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(correlation, center=True, square=True, annot=True, cmap="gist_gray",fmt='.2f', 
                 annot_kws={'size': 10});

# %% [markdown]
# > ## Exploring the Portfolio 1 Dataset:

# %% [markdown]
# >> ### Data Types:

# %%
data_types_portfolio_1 = portfolio_1.dtypes
data_types_portfolio_1
# Out:
# Unnamed: 0                                         int64
# id                                                object
# fl_matriz                                           bool
# de_natureza_juridica                              object
# sg_uf                                             object
# natureza_juridica_macro                           object
# de_ramo                                           object
# setor                                             object
# idade_empresa_anos                               float64
# idade_emp_cat                                     object
# fl_me                                               bool
# fl_sa                                               bool
# fl_epp                                              bool
# fl_mei                                              bool
# fl_ltda                                             bool
# dt_situacao                                       object
# fl_st_especial                                      bool
# fl_email                                            bool
# fl_telefone                                         bool
# fl_rm                                             object
# nm_divisao                                        object
# nm_segmento                                       object
# fl_spa                                              bool
# fl_antt                                             bool
# fl_veiculo                                          bool
# vl_total_tancagem                                float64
# vl_total_veiculos_antt                           float64
# vl_total_veiculos_leves                          float64
# vl_total_veiculos_pesados                        float64
# fl_optante_simples                                object
#                                                   ...
# idade_de_34_a_38                                 float64
# idade_de_39_a_43                                 float64
# idade_de_44_a_48                                 float64
# idade_de_49_a_53                                 float64
# idade_de_54_a_58                                 float64
# idade_acima_de_58                                float64
# grau_instrucao_macro_analfabeto                  float64
# grau_instrucao_macro_escolaridade_fundamental    float64
# grau_instrucao_macro_escolaridade_media          float64
# grau_instrucao_macro_escolaridade_superior       float64
# grau_instrucao_macro_desconhecido                float64
# total                                            float64
# meses_ultima_contratacaco                        float64
# qt_admitidos_12meses                             float64
# qt_desligados_12meses                            float64
# qt_desligados                                    float64
# qt_admitidos                                     float64
# media_meses_servicos_all                         float64
# max_meses_servicos_all                           float64
# min_meses_servicos_all                           float64
# media_meses_servicos                             float64
# max_meses_servicos                               float64
# min_meses_servicos                               float64
# qt_funcionarios                                  float64
# qt_funcionarios_12meses                          float64
# qt_funcionarios_24meses                          float64
# tx_crescimento_12meses                           float64
# tx_crescimento_24meses                           float64
# tx_rotatividade                                  float64
# qt_filiais                                         int64
# Length: 182, dtype: object

# %% [markdown]
# >> ### Number of columns with NA's:

# %%
qt_cols_na_portfolio_1 = len(portfolio_1.columns[portfolio_1.isna().any()])
qt_cols_na_portfolio_1
# Out:
# 151

# %% [markdown]
# >> ### Number of columns without NA's:

# %%
qt_cols_wtt_na_portfolio_1 = len(portfolio_1.columns) - qt_cols_na_portfolio_1
qt_cols_wtt_na_portfolio_1
# Out:
# 31

# %% [markdown]
# >> ### NA's count per column:

# %%
qt_na_per_col_portfolio_1 = portfolio_1.isna().sum().sort_values(ascending=False)
qt_na_per_col_portfolio_1
# Out:
# coligada_mais_antiga_baixada         555
# coligada_mais_nova_baixada           555
# vl_total_tancagem                    555
# vl_total_veiculos_antt               555
# idade_media_coligadas_baixadas       555
# qt_alteracao_socio_365d              555
# qt_alteracao_socio_180d              555
# vl_total_tancagem_grupo              555
# vl_total_veiculos_antt_grupo         555
# grau_instrucao_macro_desconhecido    555
# qt_alteracao_socio_90d               555
# qt_alteracao_socio_total             555
# grau_instrucao_macro_analfabeto      554
# qt_socios_pj_inaptos                 553
# qt_socios_pj_baixados                553
# qt_socios_pj_suspensos               553
# vl_idade_maxima_socios_pj            553
# vl_idade_minima_socios_pj            553
# qt_socios_pj_nulos                   553
# vl_idade_media_socios_pj             553
# qt_socios_pj_ativos                  553
# vl_potenc_cons_oleo_gas              552
# qt_socios_pep                        551
# qt_art                               551
# idade_ate_18                         551
# qt_socios_st_suspensa                548
# idade_de_54_a_58                     541
# idade_acima_de_58                    540
# min_filiais_coligados                540
# total_filiais_coligados              540
#                                     ...
# id                                     0
# fl_sa                                  0
# idade_empresa_anos                     0
# fl_epp                                 0
# fl_mei                                 0
# idade_emp_cat                          0
# sg_uf                                  0
# setor                                  0
# de_ramo                                0
# dt_situacao                            0
# natureza_juridica_macro                0
# de_natureza_juridica                   0
# fl_matriz                              0
# fl_ltda                                0
# qt_filiais                             0
# fl_st_especial                         0
# fl_email                               0
# fl_telefone                            0
# fl_rm                                  0
# nm_divisao                             0
# nm_segmento                            0
# fl_spa                                 0
# fl_antt                                0
# fl_veiculo                             0
# vl_total_veiculos_pesados_grupo        0
# vl_total_veiculos_leves_grupo          0
# sg_uf_matriz                           0
# fl_simples_irregular                   0
# fl_passivel_iss                        0
# Unnamed: 0                             0
# Length: 182, dtype: int64

# %% [markdown]
# >> ### Dataframe portfolio 1 without columns with NA's:

# %%
portfolio_1_T1 = portfolio_1.dropna(axis = 'columns')
portfolio_1_T1 = portfolio_1_T1.drop(['Unnamed: 0'], axis = 1) # Delete column 'Unnamed: 0'
portfolio_1_T1.head()
# Out:
#                                                   id  fl_matriz  \
# 0  dabe79bec87c88ae04e869bf6bd321ee5e1893cecf6625...       True
# 1  32e5f4e10932153a7ba869cb0386e7e02d49d2461046b8...      False
# 2  a95d6f30bba445bd3d6b0c5b36f865b38ec01d17336090...       True
# 3  6cb309685cea0b6d2988818792ec2e6fcb2bd02e0afa9e...       True
# 4  f72aa7fa6787b0a5a1c88885b6120850df8ee0f71adc25...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 1          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    MA                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 4  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#               de_ramo     setor  idade_empresa_anos idade_emp_cat  fl_me  ...  \
# 0  COMERCIO VAREJISTA  COMERCIO            0.646575          <= 1  False  ...
# 1  COMERCIO VAREJISTA  COMERCIO            6.586301        5 a 10  False  ...
# 2  COMERCIO VAREJISTA  COMERCIO            8.010959        5 a 10  False  ...
# 3  COMERCIO VAREJISTA  COMERCIO           20.863014          > 20  False  ...
# 4  COMERCIO VAREJISTA  COMERCIO           18.726027       15 a 20  False  ...
#
#                                          nm_segmento  fl_spa  fl_antt  \
# 0  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...   False    False
# 1  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...   False    False
# 2  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...   False    False
# 3  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...   False    False
# 4  COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES E ...   False    False
#
#    fl_veiculo vl_total_veiculos_pesados_grupo  vl_total_veiculos_leves_grupo  \
# 0       False                               0                              0
# 1       False                               0                              0
# 2       False                               0                              0
# 3       False                               0                              0
# 4       False                               0                              0
#
#    sg_uf_matriz  fl_simples_irregular fl_passivel_iss qt_filiais
# 0            PI                 False           False          0
# 1            MA                 False           False          4
# 2            MA                 False           False          0
# 3            RN                 False           False          0
# 4            RN                 False           False          3
#
# [5 rows x 30 columns]

# %%
print("After this first handling, the portfolio 1 dimensions (row, column) are:", portfolio_1_T1.shape)
# Out:
# After this first handling, the portfolio 1 dimensions (row, column) are: (555, 30)

# %% [markdown]
# >> ### Unique Values:

# %%
# First an adjustment in the 'idade_empresa_anos' column that floats:
portfolio_1_T1['idade_empresa_anos'] = portfolio_1_T1['idade_empresa_anos'].round().astype(int)

qt_val_uni_portfolio_1_T1 = portfolio_1_T1.nunique()
data_types_portfolio_1_T1 = portfolio_1_T1.dtypes
portfolio_1_T1_qt_un_tp = pd.concat([qt_val_uni_portfolio_1_T1, data_types_portfolio_1_T1], axis = 1).reset_index()
portfolio_1_T1_qt_un_tp.columns = ['Column', 'Unique_values', 'Tipo']
portfolio_1_T1_qt_un_tp
# Out:
#                              Column  Unique_values    Tipo
# 0                                id            555  object
# 1                         fl_matriz              2    bool
# 2              de_natureza_juridica              6  object
# 3                             sg_uf              6  object
# 4           natureza_juridica_macro              2  object
# 5                           de_ramo              2  object
# 6                             setor              3  object
# 7                idade_empresa_anos             44   int64
# 8                     idade_emp_cat              6  object
# 9                             fl_me              2    bool
# 10                            fl_sa              2    bool
# 11                           fl_epp              1    bool
# 12                           fl_mei              2    bool
# 13                          fl_ltda              1    bool
# 14                      dt_situacao            416  object
# 15                   fl_st_especial              1    bool
# 16                         fl_email              2    bool
# 17                      fl_telefone              2    bool
# 18                            fl_rm              2  object
# 19                       nm_divisao              8  object
# 20                      nm_segmento              2  object
# 21                           fl_spa              1    bool
# 22                          fl_antt              2    bool
# 23                       fl_veiculo              2    bool
# 24  vl_total_veiculos_pesados_grupo              9   int64
# 25    vl_total_veiculos_leves_grupo             10   int64
# 26                     sg_uf_matriz              7  object
# 27             fl_simples_irregular              1    bool
# 28                  fl_passivel_iss              2    bool
# 29                       qt_filiais             15   int64

# %% [markdown]
# >> ### Frequency of Unique Values:

# %%
freq_val_uni_portfolio_1_T1 = portfolio_1_T1.drop(['id'], axis =1).apply(lambda x: [x.value_counts().to_dict()])
freq_val_uni_portfolio_1_T1
# Out:
# fl_matriz                                                   [{True: 519, False: 36}]
# de_natureza_juridica               [{'EMPRESARIO INDIVIDUAL': 432, 'SOCIEDADE EMP...
# sg_uf                              [{'MA': 157, 'RN': 116, 'PI': 103, 'AM': 94, '...
# natureza_juridica_macro             [{'OUTROS': 447, 'ENTIDADES EMPRESARIAIS': 108}]
# de_ramo                            [{'COMERCIO VAREJISTA': 496, 'BENS DE CONSUMO'...
# setor                              [{'COMERCIO': 496, 'INDUSTRIA': 52, 'SERVIÇO':...
# idade_empresa_anos                 [{1: 61, 2: 43, 5: 43, 3: 35, 4: 35, 8: 33, 7:...
# idade_emp_cat                      [{'1 a 5': 157, '5 a 10': 144, '> 20': 92, '<=...
# fl_me                                                        [{False: 553, True: 2}]
# fl_sa                                                        [{False: 546, True: 9}]
# fl_epp                                                                [{False: 555}]
# fl_mei                                                     [{False: 337, True: 218}]
# fl_ltda                                                               [{False: 555}]
# dt_situacao                        [{'2005-11-03': 100, '2010-10-26': 4, '2006-12...
# fl_st_especial                                                        [{False: 555}]
# fl_email                                                   [{False: 300, True: 255}]
# fl_telefone                                                [{True: 400, False: 155}]
# fl_rm                                                     [{'NAO': 311, 'SIM': 244}]
# nm_divisao                         [{'COMERCIO VAREJISTA': 496, 'FABRICACAO DE PR...
# nm_segmento                        [{'COMERCIO; REPARACAO DE VEICULOS AUTOMOTORES...
# fl_spa                                                                [{False: 555}]
# fl_antt                                                      [{False: 551, True: 4}]
# fl_veiculo                                                  [{False: 517, True: 38}]
# vl_total_veiculos_pesados_grupo    [{0: 535, 1: 9, 8: 2, 7: 2, 4: 2, 2: 2, 382: 1...
# vl_total_veiculos_leves_grupo      [{0: 513, 1: 23, 3: 7, 2: 5, 6: 2, 17: 1, 10: ...
# sg_uf_matriz                       [{'MA': 156, 'RN': 116, 'PI': 103, 'AM': 93, '...
# fl_simples_irregular                                                  [{False: 555}]
# fl_passivel_iss                                            [{False: 442, True: 113}]
# qt_filiais                         [{0: 498, 1: 27, 3: 6, 5: 4, 4: 4, 2: 4, 6: 3,...
# dtype: object

# %% [markdown]
# >> ### Data visualization:

# %% [markdown]
# >> ### Graphs:

# %%
f, axes= plt.subplots(8, 3, figsize=(18, 40))

sns.countplot(data=portfolio_1_T1, x="fl_matriz", palette = 'gist_gray', order = portfolio_1_T1['fl_matriz'].value_counts().index, ax=axes[0,0]);
axes[0,0].set_title("fl_matriz")
axes[0,0].set_ylabel("")
axes[0,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="sg_uf", palette = 'gist_gray', order = portfolio_1_T1['sg_uf'].value_counts().index, ax=axes[0,1]);
axes[0,1].set_title("sg_uf")
axes[0,1].set_ylabel("")
axes[0,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="idade_emp_cat", palette = 'gist_gray', order = portfolio_1_T1['idade_emp_cat'].value_counts().index, ax=axes[0,2]);
axes[0,2].set_title("idade_emp_cat")
axes[0,2].set_ylabel("")
axes[0,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_me", palette = 'gist_gray', order = portfolio_1_T1['fl_me'].value_counts().index, ax=axes[1,0]);
axes[1,0].set_title("fl_me")
axes[1,0].set_ylabel("")
axes[1,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_sa", palette = 'gist_gray', order = portfolio_1_T1['fl_sa'].value_counts().index, ax=axes[1,1]);
axes[1,1].set_title("fl_sa")
axes[1,1].set_ylabel("")
axes[1,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_mei", palette = 'gist_gray', order = portfolio_1_T1['fl_mei'].value_counts().index, ax=axes[1,2]);
axes[1,2].set_title("fl_mei")
axes[1,2].set_ylabel("")
axes[1,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_ltda", palette = 'gist_gray', order = portfolio_1_T1['fl_ltda'].value_counts().index, ax=axes[2,0]);
axes[2,0].set_title("fl_ltda")
axes[2,0].set_ylabel("")
axes[2,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_st_especial", palette = 'gist_gray', order = portfolio_1_T1['fl_st_especial'].value_counts().index, ax=axes[2,1]);
axes[2,1].set_title("fl_st_especial")
axes[2,1].set_ylabel("")
axes[2,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_email", palette = 'gist_gray', order = portfolio_1_T1['fl_email'].value_counts().index, ax=axes[2,2]);
axes[2,2].set_title("fl_email")
axes[2,2].set_ylabel("")
axes[2,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_telefone", palette = 'gist_gray', order = portfolio_1_T1['fl_telefone'].value_counts().index, ax=axes[3,0]);
axes[3,0].set_title("fl_telefone")
axes[3,0].set_ylabel("")
axes[3,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_rm", palette = 'gist_gray', order = portfolio_1_T1['fl_rm'].value_counts().index, ax=axes[3,1]);
axes[3,1].set_title("fl_rm")
axes[3,1].set_ylabel("")
axes[3,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_epp", palette = 'gist_gray', order = portfolio_1_T1['fl_epp'].value_counts().index, ax=axes[3,2]);
axes[3,2].set_title("fl_epp")
axes[3,2].set_ylabel("")
axes[3,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="setor", palette = 'gist_gray', order = portfolio_1_T1['setor'].value_counts().index, ax=axes[4,0]);
axes[4,0].set_title("setor")
axes[4,0].set_ylabel("")
axes[4,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="de_ramo", palette = 'gist_gray', order = portfolio_1_T1['de_ramo'].value_counts().index, ax=axes[4,1]);
plt.xticks(rotation=90)
axes[4,1].set_title("de_ramo")
axes[4,1].set_ylabel("")
axes[4,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_passivel_iss", palette = 'gist_gray', order = portfolio_1_T1['fl_passivel_iss'].value_counts().index, ax=axes[4,2]);
axes[4,2].set_title("fl_passivel_iss")
axes[4,2].set_ylabel("")
axes[4,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_spa", palette = 'gist_gray', order = portfolio_1_T1['fl_spa'].value_counts().index, ax=axes[5,0]);
axes[5,0].set_title("fl_spa")
axes[5,0].set_ylabel("")
axes[5,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_antt", palette = 'gist_gray', order = portfolio_1_T1['fl_antt'].value_counts().index, ax=axes[5,1]);
axes[5,1].set_title("fl_antt")
axes[5,1].set_ylabel("")
axes[5,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_veiculo", palette = 'gist_gray', order = portfolio_1_T1['fl_veiculo'].value_counts().index, ax=axes[5,2]);
axes[5,2].set_title("fl_veiculo")
axes[5,2].set_ylabel("")
axes[5,2].set_xlabel("")


sns.countplot(data=portfolio_1_T1, x="vl_total_veiculos_pesados_grupo", palette = 'gist_gray', order = portfolio_1_T1['vl_total_veiculos_pesados_grupo'].value_counts().index, ax=axes[6,0]);
axes[6,0].set_title("vl_total_veiculos_pesados_grupo")
axes[6,0].set_ylabel("")
axes[6,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="vl_total_veiculos_leves_grupo", palette = 'gist_gray', order = portfolio_1_T1['vl_total_veiculos_leves_grupo'].value_counts().index, ax=axes[6,1]);
axes[6,1].set_title("vl_total_veiculos_leves_grupo")
axes[6,1].set_ylabel("")
axes[6,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="sg_uf_matriz", palette = 'gist_gray', order = portfolio_1_T1['sg_uf_matriz'].value_counts().index, ax=axes[6,2]);
axes[6,2].set_title("sg_uf_matriz")
axes[6,2].set_ylabel("")
axes[6,2].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="qt_filiais", palette = 'gist_gray', order = portfolio_1_T1['qt_filiais'].value_counts().index, ax=axes[7,0]);
axes[7,0].set_title("qt_filiais")
axes[7,0].set_ylabel("")
axes[7,0].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_simples_irregular", palette = 'gist_gray', order = portfolio_1_T1['fl_simples_irregular'].value_counts().index, ax=axes[7,1]);
axes[7,1].set_title("fl_simples_irregular")
axes[7,1].set_ylabel("")
axes[7,1].set_xlabel("")

sns.countplot(data=portfolio_1_T1, x="fl_passivel_iss", palette = 'gist_gray', order = portfolio_1_T1['fl_passivel_iss'].value_counts().index, ax=axes[7,2]);
axes[7,2].set_title("fl_passivel_iss")
axes[7,2].set_ylabel("")
axes[7,2].set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_1_T1, x="nm_divisao", palette = 'gist_gray', order = portfolio_1_T1['nm_divisao'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_divisao")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_1_T1, x="nm_segmento", palette = 'gist_gray', order = portfolio_1_T1['nm_segmento'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_segmento")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_1_T1, x="de_natureza_juridica", palette = 'gist_gray', order = portfolio_1_T1['de_natureza_juridica'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_natureza_juridica")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_1_T1, x="natureza_juridica_macro", palette = 'gist_gray', order = portfolio_1_T1['natureza_juridica_macro'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("natureza_juridica_macro")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_1_T1, x="idade_empresa_anos", palette = 'gist_gray', order = portfolio_1_T1['idade_empresa_anos'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("idade_empresa_anos")
ax.set_ylabel("")
ax.set_xlabel("")

plt.show()

# %% [markdown]
# >> ### Correlations:

# %%
# Convert object columns to numeric value
portfolio_1_T1['de_natureza_juridica'] = pd.factorize(portfolio_1_T1['de_natureza_juridica'])[0]
portfolio_1_T1['sg_uf'] = pd.factorize(portfolio_1_T1['sg_uf'])[0]
portfolio_1_T1['natureza_juridica_macro'] = pd.factorize(portfolio_1_T1['natureza_juridica_macro'])[0]
portfolio_1_T1['de_ramo'] = pd.factorize(portfolio_1_T1['de_ramo'])[0]
portfolio_1_T1['setor'] = pd.factorize(portfolio_1_T1['setor'])[0]
portfolio_1_T1['idade_emp_cat'] = pd.factorize(portfolio_1_T1['idade_emp_cat'])[0]
portfolio_1_T1['dt_situacao'] = pd.factorize(portfolio_1_T1['dt_situacao'])[0]
portfolio_1_T1['fl_rm'] = pd.factorize(portfolio_1_T1['fl_rm'])[0]
portfolio_1_T1['nm_divisao'] = pd.factorize(portfolio_1_T1['nm_divisao'])[0]
portfolio_1_T1['nm_segmento'] = pd.factorize(portfolio_1_T1['nm_segmento'])[0]
portfolio_1_T1['sg_uf_matriz'] = pd.factorize(portfolio_1_T1['sg_uf_matriz'])[0]

# %%
correlation = portfolio_1_T1.corr(method="pearson")
correlation
# Out:
#                                  fl_matriz  de_natureza_juridica     sg_uf  \
# fl_matriz                         1.000000             -0.226851  0.020505
# de_natureza_juridica             -0.226851              1.000000  0.099342
# sg_uf                             0.020505              0.099342  1.000000
# natureza_juridica_macro          -0.277094              0.714283  0.045898
# de_ramo                           0.019630              0.097279  0.026161
# setor                             0.025994              0.102201  0.025861
# idade_empresa_anos               -0.038564              0.142549  0.075169
# idade_emp_cat                    -0.051591              0.055111 -0.056744
# fl_me                            -0.106251             -0.028280  0.091561
# fl_sa                            -0.024108             -0.060375 -0.088631
# fl_epp                                 NaN                   NaN       NaN
# fl_mei                            0.211827             -0.378223  0.009546
# fl_ltda                                NaN                   NaN       NaN
# dt_situacao                      -0.009423             -0.022265  0.015712
# fl_st_especial                         NaN                   NaN       NaN
# fl_email                          0.007935              0.054303  0.040729
# fl_telefone                       0.080651             -0.078049  0.000618
# fl_rm                             0.041669              0.041075 -0.107691
# nm_divisao                        0.017450              0.087391 -0.000345
# nm_segmento                       0.019630              0.097279  0.026161
# fl_spa                                 NaN                   NaN       NaN
# fl_antt                           0.022440              0.111207  0.053969
# fl_veiculo                        0.013466              0.100514 -0.043943
# vl_total_veiculos_pesados_grupo  -0.192125              0.293334 -0.060064
# vl_total_veiculos_leves_grupo    -0.196777              0.301764 -0.056833
# sg_uf_matriz                     -0.010834              0.112442  0.983921
# fl_simples_irregular                   NaN                   NaN       NaN
# fl_passivel_iss                  -0.012177              0.103835  0.066457
# qt_filiais                       -0.273559              0.310853 -0.063600
#
#                                  natureza_juridica_macro   de_ramo     setor  \
# fl_matriz                                      -0.277094  0.019630  0.025994
# de_natureza_juridica                            0.714283  0.097279  0.102201
# sg_uf                                           0.045898  0.026161  0.025861
# natureza_juridica_macro                         1.000000  0.081492  0.077716
# de_ramo                                         0.081492  1.000000  0.956291
# setor                                           0.077716  0.956291  1.000000
# idade_empresa_anos                              0.200709 -0.040215 -0.046803
# idade_emp_cat                                   0.044828  0.006874  0.007584
# fl_me                                          -0.029560 -0.020741 -0.019835
# fl_sa                                          -0.063108 -0.044280 -0.042345
# fl_epp                                               NaN       NaN       NaN
# fl_mei                                         -0.395341  0.069726  0.062169
# fl_ltda                                              NaN       NaN       NaN
# dt_situacao                                    -0.112417 -0.003545 -0.001106
# fl_st_especial                                       NaN       NaN       NaN
# fl_email                                       -0.005677  0.010462  0.016803
# fl_telefone                                    -0.180956  0.006221  0.004817
# fl_rm                                           0.050606  0.036054  0.030041
# nm_divisao                                      0.076834  0.883519  0.924812
# nm_segmento                                     0.081492  1.000000  0.956291
# fl_spa                                               NaN       NaN       NaN
# fl_antt                                         0.173339  0.039721  0.030976
# fl_veiculo                                      0.119039  0.045376  0.068881
# vl_total_veiculos_pesados_grupo                 0.106674 -0.013205 -0.013137
# vl_total_veiculos_leves_grupo                   0.111139 -0.007569 -0.004586
# sg_uf_matriz                                    0.047261  0.035948  0.036110
# fl_simples_irregular                                 NaN       NaN       NaN
# fl_passivel_iss                                 0.147056  0.144987  0.193127
# qt_filiais                                      0.138582 -0.022604 -0.021980
#
#                                  idade_empresa_anos  idade_emp_cat     fl_me  \
# fl_matriz                                 -0.038564      -0.051591 -0.106251
# de_natureza_juridica                       0.142549       0.055111 -0.028280
# sg_uf                                      0.075169      -0.056744  0.091561
# natureza_juridica_macro                    0.200709       0.044828 -0.029560
# de_ramo                                   -0.040215       0.006874 -0.020741
# setor                                     -0.046803       0.007584 -0.019835
# idade_empresa_anos                         1.000000      -0.011843  0.052076
# idade_emp_cat                             -0.011843       1.000000 -0.037536
# fl_me                                      0.052076      -0.037536  1.000000
# fl_sa                                      0.002541       0.022909 -0.007721
# fl_epp                                          NaN            NaN       NaN
# fl_mei                                    -0.550466      -0.101096 -0.048369
# fl_ltda                                         NaN            NaN       NaN
# dt_situacao                               -0.416244       0.003026 -0.037862
# fl_st_especial                                  NaN            NaN       NaN
# fl_email                                  -0.408054      -0.081509  0.004892
# fl_telefone                               -0.620391      -0.021385 -0.029586
# fl_rm                                      0.015522      -0.069457 -0.053268
# nm_divisao                                -0.036867      -0.002193 -0.018325
# nm_segmento                               -0.040215       0.006874 -0.020741
# fl_spa                                          NaN            NaN       NaN
# fl_antt                                    0.056125       0.067234 -0.005124
# fl_veiculo                                 0.168237       0.023480 -0.016304
# vl_total_veiculos_pesados_grupo            0.009335       0.079513 -0.003178
# vl_total_veiculos_leves_grupo              0.017497       0.080393 -0.003840
# sg_uf_matriz                               0.082956      -0.058512  0.082978
# fl_simples_irregular                            NaN            NaN       NaN
# fl_passivel_iss                           -0.189192      -0.024697 -0.030407
# qt_filiais                                 0.012852       0.073533 -0.002720
#
#                                     fl_sa  ...  nm_segmento  fl_spa   fl_antt  \
# fl_matriz                       -0.024108  ...     0.019630     NaN  0.022440
# de_natureza_juridica            -0.060375  ...     0.097279     NaN  0.111207
# sg_uf                           -0.088631  ...     0.026161     NaN  0.053969
# natureza_juridica_macro         -0.063108  ...     0.081492     NaN  0.173339
# de_ramo                         -0.044280  ...     1.000000     NaN  0.039721
# setor                           -0.042345  ...     0.956291     NaN  0.030976
# idade_empresa_anos               0.002541  ...    -0.040215     NaN  0.056125
# idade_emp_cat                    0.022909  ...     0.006874     NaN  0.067234
# fl_me                           -0.007721  ...    -0.020741     NaN -0.005124
# fl_sa                            1.000000  ...    -0.044280     NaN -0.010939
# fl_epp                                NaN  ...          NaN     NaN       NaN
# fl_mei                          -0.103261  ...     0.069726     NaN -0.068528
# fl_ltda                               NaN  ...          NaN     NaN       NaN
# dt_situacao                     -0.028245  ...    -0.003545     NaN -0.021433
# fl_st_especial                        NaN  ...          NaN     NaN       NaN
# fl_email                        -0.032493  ...     0.010462     NaN  0.006931
# fl_telefone                     -0.079062  ...     0.006221     NaN  0.005560
# fl_rm                            0.001243  ...     0.036054     NaN -0.032554
# nm_divisao                      -0.039122  ...     0.883519     NaN  0.010609
# nm_segmento                     -0.044280  ...     1.000000     NaN  0.039721
# fl_spa                                NaN  ...          NaN     NaN       NaN
# fl_antt                         -0.010939  ...     0.039721     NaN  1.000000
# fl_veiculo                       0.021678  ...     0.045376     NaN  0.229930
# vl_total_veiculos_pesados_grupo -0.006785  ...    -0.013205     NaN  0.003339
# vl_total_veiculos_leves_grupo   -0.008197  ...    -0.007569     NaN  0.014621
# sg_uf_matriz                    -0.086538  ...     0.035948     NaN  0.047253
# fl_simples_irregular                  NaN  ...          NaN     NaN       NaN
# fl_passivel_iss                 -0.064916  ...     0.144987     NaN  0.115612
# qt_filiais                      -0.008875  ...    -0.022604     NaN -0.002545
#
#                                  fl_veiculo  vl_total_veiculos_pesados_grupo  \
# fl_matriz                          0.013466                        -0.192125
# de_natureza_juridica               0.100514                         0.293334
# sg_uf                             -0.043943                        -0.060064
# natureza_juridica_macro            0.119039                         0.106674
# de_ramo                            0.045376                        -0.013205
# setor                              0.068881                        -0.013137
# idade_empresa_anos                 0.168237                         0.009335
# idade_emp_cat                      0.023480                         0.079513
# fl_me                             -0.016304                        -0.003178
# fl_sa                              0.021678                        -0.006785
# fl_epp                                  NaN                              NaN
# fl_mei                            -0.188834                        -0.042504
# fl_ltda                                 NaN                              NaN
# dt_situacao                       -0.105258                        -0.007404
# fl_st_especial                          NaN                              NaN
# fl_email                          -0.035210                         0.040238
# fl_telefone                       -0.069770                         0.028214
# fl_rm                             -0.038901                        -0.035226
# nm_divisao                         0.039883                        -0.013446
# nm_segmento                        0.045376                        -0.013205
# fl_spa                                  NaN                              NaN
# fl_antt                            0.229930                         0.003339
# fl_veiculo                         1.000000                        -0.002507
# vl_total_veiculos_pesados_grupo   -0.002507                         1.000000
# vl_total_veiculos_leves_grupo      0.044004                         0.994511
# sg_uf_matriz                      -0.049815                        -0.057508
# fl_simples_irregular                    NaN                              NaN
# fl_passivel_iss                    0.040096                        -0.019307
# qt_filiais                        -0.004809                         0.984178
#
#                                  vl_total_veiculos_leves_grupo  sg_uf_matriz  \
# fl_matriz                                            -0.196777     -0.010834
# de_natureza_juridica                                  0.301764      0.112442
# sg_uf                                                -0.056833      0.983921
# natureza_juridica_macro                               0.111139      0.047261
# de_ramo                                              -0.007569      0.035948
# setor                                                -0.004586      0.036110
# idade_empresa_anos                                    0.017497      0.082956
# idade_emp_cat                                         0.080393     -0.058512
# fl_me                                                -0.003840      0.082978
# fl_sa                                                -0.008197     -0.086538
# fl_epp                                                     NaN           NaN
# fl_mei                                               -0.050483      0.001558
# fl_ltda                                                    NaN           NaN
# dt_situacao                                          -0.012030      0.015413
# fl_st_especial                                             NaN           NaN
# fl_email                                              0.038606      0.033351
# fl_telefone                                           0.026034     -0.007858
# fl_rm                                                -0.036467     -0.119867
# nm_divisao                                           -0.007255      0.001785
# nm_segmento                                          -0.007569      0.035948
# fl_spa                                                     NaN           NaN
# fl_antt                                               0.014621      0.047253
# fl_veiculo                                            0.044004     -0.049815
# vl_total_veiculos_pesados_grupo                       0.994511     -0.057508
# vl_total_veiculos_leves_grupo                         1.000000     -0.053195
# sg_uf_matriz                                         -0.053195      1.000000
# fl_simples_irregular                                       NaN           NaN
# fl_passivel_iss                                      -0.017006      0.071426
# qt_filiais                                            0.979017     -0.058635
#
#                                  fl_simples_irregular  fl_passivel_iss  \
# fl_matriz                                         NaN        -0.012177
# de_natureza_juridica                              NaN         0.103835
# sg_uf                                             NaN         0.066457
# natureza_juridica_macro                           NaN         0.147056
# de_ramo                                           NaN         0.144987
# setor                                             NaN         0.193127
# idade_empresa_anos                                NaN        -0.189192
# idade_emp_cat                                     NaN        -0.024697
# fl_me                                             NaN        -0.030407
# fl_sa                                             NaN        -0.064916
# fl_epp                                            NaN              NaN
# fl_mei                                            NaN         0.033116
# fl_ltda                                           NaN              NaN
# dt_situacao                                       NaN         0.170233
# fl_st_especial                                    NaN              NaN
# fl_email                                          NaN         0.207237
# fl_telefone                                       NaN         0.145200
# fl_rm                                             NaN        -0.042184
# nm_divisao                                        NaN         0.157071
# nm_segmento                                       NaN         0.144987
# fl_spa                                            NaN              NaN
# fl_antt                                           NaN         0.115612
# fl_veiculo                                        NaN         0.040096
# vl_total_veiculos_pesados_grupo                   NaN        -0.019307
# vl_total_veiculos_leves_grupo                     NaN        -0.017006
# sg_uf_matriz                                      NaN         0.071426
# fl_simples_irregular                              NaN              NaN
# fl_passivel_iss                                   NaN         1.000000
# qt_filiais                                        NaN        -0.020532
#
#                                  qt_filiais
# fl_matriz                         -0.273559
# de_natureza_juridica               0.310853
# sg_uf                             -0.063600
# natureza_juridica_macro            0.138582
# de_ramo                           -0.022604
# setor                             -0.021980
# idade_empresa_anos                 0.012852
# idade_emp_cat                      0.073533
# fl_me                             -0.002720
# fl_sa                             -0.008875
# fl_epp                                  NaN
# fl_mei                            -0.061090
# fl_ltda                                 NaN
# dt_situacao                        0.000401
# fl_st_especial                          NaN
# fl_email                           0.035284
# fl_telefone                        0.025070
# fl_rm                             -0.044078
# nm_divisao                        -0.019818
# nm_segmento                       -0.022604
# fl_spa                                  NaN
# fl_antt                           -0.002545
# fl_veiculo                        -0.004809
# vl_total_veiculos_pesados_grupo    0.984178
# vl_total_veiculos_leves_grupo      0.979017
# sg_uf_matriz                      -0.058635
# fl_simples_irregular                    NaN
# fl_passivel_iss                   -0.020532
# qt_filiais                         1.000000
#
# [29 rows x 29 columns]

# %%
cor_market_portfolio_1_T1 = portfolio_1_T1.drop(['fl_epp','fl_ltda','fl_st_especial', 'fl_spa', 'fl_simples_irregular'], axis = 1)
correlation = cor_market_portfolio_1_T1.corr(method="pearson")
f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(correlation, center=True, square=True, annot=True, cmap="gist_gray",fmt='.2f', 
                 annot_kws={'size': 10});

# %% [markdown]
# >> ### Overview about Company 1's clients:

# %% [markdown]
# - Customers provide at least 30 data (already counting the id);
# - They have less than 20 years in the market, most of them have less than 10 years;
# - Most are from the commerce sector, but there are industries and services as well;
# - Are from the retail trade or consumer goods industry;
# - Operate in vehicle repair, various factories and manufacturing industry;
# - Most are legal in nature "Individual Entrepreneurs";
# - The data: fl_ltda, ff_st_special, fl_epp, fl_spa and fl_simples_irregular always have a value of “False”.

# %% [markdown]
# > ## Exploring the Portfolio 2 Dataset:

# %% [markdown]
# >> ### Data types:

# %%
# The dataset portifolio_2 has only the column 'id', we will complete with the other data that are present in the dataset market.
portfolio_2_T1 = pd.DataFrame(portfolio_2['id'])
portfolio_2_T1 = pd.merge(portfolio_2_T1, market, on='id', how='left')

data_types_portfolio_2_T1 = portfolio_2_T1.dtypes
data_types_portfolio_2_T1
# Out:
# id                                                object
# Unnamed: 0                                         int64
# fl_matriz                                           bool
# de_natureza_juridica                              object
# sg_uf                                             object
# natureza_juridica_macro                           object
# de_ramo                                           object
# setor                                             object
# idade_empresa_anos                               float64
# idade_emp_cat                                     object
# fl_me                                               bool
# fl_sa                                               bool
# fl_epp                                              bool
# fl_mei                                              bool
# fl_ltda                                             bool
# dt_situacao                                       object
# fl_st_especial                                      bool
# fl_email                                            bool
# fl_telefone                                         bool
# fl_rm                                             object
# nm_divisao                                        object
# nm_segmento                                       object
# fl_spa                                            object
# fl_antt                                           object
# fl_veiculo                                        object
# vl_total_tancagem                                float64
# vl_total_veiculos_antt                           float64
# vl_total_veiculos_leves                          float64
# vl_total_veiculos_pesados                        float64
# fl_optante_simples                                object
#                                                   ...
# idade_de_34_a_38                                 float64
# idade_de_39_a_43                                 float64
# idade_de_44_a_48                                 float64
# idade_de_49_a_53                                 float64
# idade_de_54_a_58                                 float64
# idade_acima_de_58                                float64
# grau_instrucao_macro_analfabeto                  float64
# grau_instrucao_macro_escolaridade_fundamental    float64
# grau_instrucao_macro_escolaridade_media          float64
# grau_instrucao_macro_escolaridade_superior       float64
# grau_instrucao_macro_desconhecido                float64
# total                                            float64
# meses_ultima_contratacaco                        float64
# qt_admitidos_12meses                             float64
# qt_desligados_12meses                            float64
# qt_desligados                                    float64
# qt_admitidos                                     float64
# media_meses_servicos_all                         float64
# max_meses_servicos_all                           float64
# min_meses_servicos_all                           float64
# media_meses_servicos                             float64
# max_meses_servicos                               float64
# min_meses_servicos                               float64
# qt_funcionarios                                  float64
# qt_funcionarios_12meses                          float64
# qt_funcionarios_24meses                          float64
# tx_crescimento_12meses                           float64
# tx_crescimento_24meses                           float64
# tx_rotatividade                                  float64
# qt_filiais                                         int64
# Length: 182, dtype: object

# %% [markdown]
# >> ### Number of columns with NA's:

# %%
qt_cols_na_portfolio_2_T1 = len(portfolio_2_T1.columns[portfolio_2_T1.isna().any()])
qt_cols_na_portfolio_2_T1
# Out:
# 121

# %% [markdown]
# >> ### Number of columns without NA's:

# %%
qt_cols_wtt_na_portfolio_2_T1 = len(portfolio_2_T1.columns) - qt_cols_na_portfolio_2_T1
qt_cols_wtt_na_portfolio_2_T1
# Out:
# 61

# %% [markdown]
# >> ### NA's count per column:

# %%
qt_na_per_col_portfolio_2_T1 = portfolio_2_T1.isna().sum().sort_values(ascending=False)
qt_na_per_col_portfolio_2_T1
# Out:
# qt_alteracao_socio_total               566
# grau_instrucao_macro_desconhecido      566
# qt_alteracao_socio_365d                566
# qt_alteracao_socio_180d                566
# qt_alteracao_socio_90d                 566
# coligada_mais_antiga_baixada           565
# idade_media_coligadas_baixadas         565
# coligada_mais_nova_baixada             565
# qt_socios_st_suspensa                  565
# vl_total_veiculos_antt_grupo           561
# vl_total_veiculos_antt                 561
# vl_total_tancagem                      539
# vl_total_tancagem_grupo                536
# qt_socios_pep                          534
# qt_socios_pj_nulos                     515
# qt_socios_pj_baixados                  515
# qt_socios_pj_suspensos                 515
# qt_socios_pj_inaptos                   515
# vl_idade_media_socios_pj               515
# vl_idade_maxima_socios_pj              515
# vl_idade_minima_socios_pj              515
# qt_socios_pj_ativos                    515
# vl_potenc_cons_oleo_gas                472
# grau_instrucao_macro_analfabeto        449
# total_filiais_coligados                413
# media_filiais_coligados                413
# max_filiais_coligados                  413
# min_filiais_coligados                  413
# qt_socios_feminino                     369
# idade_ate_18                           351
#                                       ...
# qt_funcionarios_12meses                  0
# qt_funcionarios                          0
# min_meses_servicos                       0
# max_meses_servicos                       0
# media_meses_servicos                     0
# min_meses_servicos_all                   0
# max_meses_servicos_all                   0
# media_meses_servicos_all                 0
# qt_admitidos                             0
# qt_desligados                            0
# qt_desligados_12meses                    0
# qt_admitidos_12meses                     0
# meses_ultima_contratacaco                0
# percent_func_genero_fem                  0
# sg_uf_matriz                             0
# percent_func_genero_masc                 0
# qt_funcionarios_grupo                    0
# qt_ex_funcionarios                       0
# vl_faturamento_estimado_grupo_aux        0
# vl_faturamento_estimado_aux              0
# de_faixa_faturamento_estimado_grupo      0
# de_faixa_faturamento_estimado            0
# tx_rotatividade                          0
# fl_passivel_iss                          0
# fl_simples_irregular                     0
# de_nivel_atividade                       0
# nu_meses_rescencia                       0
# de_saude_rescencia                       0
# de_saude_tributaria                      0
# id                                       0
# Length: 182, dtype: int64

# %% [markdown]
# >> ### Dataframe portfolio 2 without columns with NA's:

# %%
portfolio_2_T2 = portfolio_2_T1.dropna(axis = 'columns')
portfolio_2_T2 = portfolio_2_T2.drop(['Unnamed: 0'], axis = 1) # Delete column'Unnamed: 0'.
portfolio_2_T2.head()
# Out:
#                                                   id  fl_matriz  \
# 0  09e95c1a84049001d086470a8f320a19b076f955a89122...       True
# 1  dc9d155f5bcd3172031e2ec9431786e8871ff4b0ff4728...       True
# 2  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 3  ff045934d90aab184dd15e66daf3b3c97193bda5449298...       True
# 4  a0ce528caab2c62497a548d0ebd9e935143ef81ed7dbf0...       True
#
#                         de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  AUTARQUIA ESTADUAL OU DO DISTRITO FEDERAL    AC   ADMINISTRACAO PUBLICA
# 1                                  MUNICIPIO    RN                  OUTROS
# 2                 SOCIEDADE SIMPLES LIMITADA    PI  ENTIDADES EMPRESARIAIS
# 3                                  MUNICIPIO    AM                  OUTROS
# 4              SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
#
#                                              de_ramo         setor  \
# 0  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 1  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 2                               SERVICOS DE EDUCACAO       SERVIÇO
# 3  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL       SERVIÇO
# 4                           PRODUTOS DE AGROPECUARIA  AGROPECUARIA
#
#    idade_empresa_anos idade_emp_cat  fl_me  ...  max_meses_servicos_all  \
# 0           11.243836       10 a 15  False  ...              357.066667
# 1           43.789041          > 20  False  ...             5014.966667
# 2           16.389041       15 a 20  False  ...              149.033333
# 3           39.671233          > 20  False  ...              555.766667
# 4           20.268493          > 20  False  ...              179.766667
#
#    min_meses_servicos_all  media_meses_servicos  max_meses_servicos  \
# 0               -6.500000             99.961009          357.066667
# 1               -9.233333            149.173091          526.133333
# 2                0.000000             65.942017          149.033333
# 3                0.966667            144.013013          555.766667
# 4               -0.566667             14.610734          134.833333
#
#   min_meses_servicos  qt_funcionarios  qt_funcionarios_12meses  \
# 0          25.533333           1361.0                   1361.0
# 1          23.200000            991.0                    991.0
# 2           4.866667            119.0                    104.0
# 3          28.300000           1829.0                   1829.0
# 4           2.933333            177.0                    130.0
#
#    qt_funcionarios_24meses tx_rotatividade qt_filiais
# 0                   1383.0        0.000000          0
# 1                   1306.0        0.000000          0
# 2                    113.0        6.250000          0
# 3                   1875.0        0.000000          1
# 4                    120.0       41.042345          0
#
# [5 rows x 60 columns]

# %%
print("After this first handling, the portfolio 2 dimensions (row, column) are:", portfolio_2_T2.shape)
# Out:
# After this first handling, the portfolio 2 dimensions (row, column) are: (566, 60)

# %% [markdown]
# >> ### Unique Values:

# %%
# First an adjustment in the 'idade_empresa_anos' column that floats:
portfolio_2_T2['idade_empresa_anos'] = portfolio_2_T2['idade_empresa_anos'].round().astype(int)
portfolio_2_T2['vl_total_veiculos_pesados_grupo'] = portfolio_2_T2['vl_total_veiculos_pesados_grupo'].round().astype(int)
portfolio_2_T2['vl_total_veiculos_leves_grupo'] = portfolio_2_T2['vl_total_veiculos_leves_grupo'].round().astype(int)
portfolio_2_T2['nu_meses_rescencia'] = portfolio_2_T2['nu_meses_rescencia'].round().astype(int)
portfolio_2_T2['vl_faturamento_estimado_aux'] = portfolio_2_T2['vl_faturamento_estimado_aux'].round().astype(int)
portfolio_2_T2['vl_faturamento_estimado_grupo_aux'] = portfolio_2_T2['vl_faturamento_estimado_grupo_aux'].round().astype(int)
portfolio_2_T2['qt_ex_funcionarios'] = portfolio_2_T2['qt_ex_funcionarios'].round().astype(int)
portfolio_2_T2['qt_funcionarios_grupo'] = portfolio_2_T2['qt_funcionarios_grupo'].round().astype(int)
portfolio_2_T2['percent_func_genero_masc'] = portfolio_2_T2['percent_func_genero_masc'].round().astype(int)
portfolio_2_T2['percent_func_genero_fem'] = portfolio_2_T2['percent_func_genero_fem'].round().astype(int)
portfolio_2_T2['total'] = portfolio_2_T2['total'].round().astype(int)
portfolio_2_T2['meses_ultima_contratacaco'] = portfolio_2_T2['meses_ultima_contratacaco'].round().astype(int)
portfolio_2_T2['qt_admitidos_12meses'] = portfolio_2_T2['qt_admitidos_12meses'].round().astype(int)
portfolio_2_T2['qt_desligados_12meses'] = portfolio_2_T2['qt_desligados_12meses'].round().astype(int)
portfolio_2_T2['qt_desligados'] = portfolio_2_T2['qt_desligados'].round().astype(int)
portfolio_2_T2['qt_admitidos'] = portfolio_2_T2['qt_admitidos'].round().astype(int)
portfolio_2_T2['media_meses_servicos_all'] = portfolio_2_T2['media_meses_servicos_all'].round().astype(int)
portfolio_2_T2['max_meses_servicos_all'] = portfolio_2_T2['max_meses_servicos_all'].round().astype(int)
portfolio_2_T2['min_meses_servicos_all'] = portfolio_2_T2['min_meses_servicos_all'].round().astype(int)
portfolio_2_T2['media_meses_servicos'] = portfolio_2_T2['media_meses_servicos'].round().astype(int)
portfolio_2_T2['max_meses_servicos'] = portfolio_2_T2['max_meses_servicos'].round().astype(int)
portfolio_2_T2['min_meses_servicos'] = portfolio_2_T2['min_meses_servicos'].round().astype(int)
portfolio_2_T2['qt_funcionarios'] = portfolio_2_T2['qt_funcionarios'].round().astype(int)
portfolio_2_T2['qt_funcionarios_12meses'] = portfolio_2_T2['qt_funcionarios_12meses'].round().astype(int)
portfolio_2_T2['qt_funcionarios_24meses'] = portfolio_2_T2['qt_funcionarios_24meses'].round().astype(int)
portfolio_2_T2['tx_rotatividade'] = portfolio_2_T2['tx_rotatividade'].round().astype(int)

# %%
qt_val_uni_portfolio_2_T2 = portfolio_2_T2.nunique()
data_types_portfolio_2_T2 = portfolio_2_T2.dtypes
portfolio_2_T2_qt_un_tp = pd.concat([qt_val_uni_portfolio_2_T2, data_types_portfolio_2_T2], axis = 1).reset_index()
portfolio_2_T2_qt_un_tp.columns = ['Column', 'Unique_values', 'Tipo']
portfolio_2_T2_qt_un_tp
# Out:
#                                  Column  Unique_values    Tipo
# 0                                    id            566  object
# 1                             fl_matriz              1    bool
# 2                  de_natureza_juridica             26  object
# 3                                 sg_uf              6  object
# 4               natureza_juridica_macro              4  object
# 5                               de_ramo             29  object
# 6                                 setor              5  object
# 7                    idade_empresa_anos             44   int64
# 8                         idade_emp_cat              3  object
# 9                                 fl_me              2    bool
# 10                                fl_sa              2    bool
# 11                               fl_epp              1    bool
# 12                               fl_mei              1    bool
# 13                              fl_ltda              2    bool
# 14                          dt_situacao            207  object
# 15                       fl_st_especial              2    bool
# 16                             fl_email              2    bool
# 17                          fl_telefone              2    bool
# 18                                fl_rm              2  object
# 19                           nm_divisao             60  object
# 20                          nm_segmento             19  object
# 21                               fl_spa              2  object
# 22                              fl_antt              2  object
# 23                           fl_veiculo              2  object
# 24                   fl_optante_simples              2  object
# 25      vl_total_veiculos_pesados_grupo             65   int64
# 26        vl_total_veiculos_leves_grupo             60   int64
# 27                     fl_optante_simei              1  object
# 28                         sg_uf_matriz              6  object
# 29                  de_saude_tributaria              5  object
# 30                   de_saude_rescencia              1  object
# 31                   nu_meses_rescencia             11   int64
# 32                   de_nivel_atividade              3  object
# 33                 fl_simples_irregular              2  object
# 34                      fl_passivel_iss              2  object
# 35        de_faixa_faturamento_estimado              6  object
# 36  de_faixa_faturamento_estimado_grupo              6  object
# 37          vl_faturamento_estimado_aux            480   int64
# 38    vl_faturamento_estimado_grupo_aux            528   int64
# 39                   qt_ex_funcionarios            425   int64
# 40                qt_funcionarios_grupo            351   int64
# 41             percent_func_genero_masc             87   int64
# 42              percent_func_genero_fem             87   int64
# 43                                total            328   int64
# 44            meses_ultima_contratacaco             49   int64
# 45                 qt_admitidos_12meses            125   int64
# 46                qt_desligados_12meses            111   int64
# 47                        qt_desligados            414   int64
# 48                         qt_admitidos            444   int64
# 49             media_meses_servicos_all            195   int64
# 50               max_meses_servicos_all            270   int64
# 51               min_meses_servicos_all             35   int64
# 52                 media_meses_servicos            198   int64
# 53                   max_meses_servicos            318   int64
# 54                   min_meses_servicos             50   int64
# 55                      qt_funcionarios            328   int64
# 56              qt_funcionarios_12meses            326   int64
# 57              qt_funcionarios_24meses            358   int64
# 58                      tx_rotatividade             69   int64
# 59                           qt_filiais             35   int64

# %% [markdown]
# >> ### Frequency of Unique Values:

# %%
freq_val_uni_portfolio_2_T2 = portfolio_2_T2.drop(['id'], axis =1).apply(lambda x: [x.value_counts().to_dict()])
freq_val_uni_portfolio_2_T2
# Out:
# fl_matriz                                                                  [{True: 566}]
# de_natureza_juridica                   [{'SOCIEDADE EMPRESARIA LIMITADA': 287, 'MUNIC...
# sg_uf                                  [{'AM': 142, 'MA': 118, 'PI': 101, 'RN': 100, ...
# natureza_juridica_macro                [{'ENTIDADES EMPRESARIAIS': 323, 'OUTROS': 152...
# de_ramo                                [{'ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE ...
# setor                                  [{'SERVIÇO': 336, 'COMERCIO': 107, 'INDUSTRIA'...
# idade_empresa_anos                     [{44: 58, 22: 51, 20: 26, 14: 25, 26: 23, 21: ...
# idade_emp_cat                              [{'> 20': 379, '10 a 15': 98, '15 a 20': 89}]
# fl_me                                                            [{False: 564, True: 2}]
# fl_sa                                                           [{False: 543, True: 23}]
# fl_epp                                                                    [{False: 566}]
# fl_mei                                                                    [{False: 566}]
# fl_ltda                                                          [{False: 562, True: 4}]
# dt_situacao                            [{'2005-11-03': 201, '2005-08-27': 36, '2005-0...
# fl_st_especial                                                   [{False: 564, True: 2}]
# fl_email                                                       [{False: 304, True: 262}]
# fl_telefone                                                    [{True: 307, False: 259}]
# fl_rm                                                         [{'SIM': 307, 'NAO': 259}]
# nm_divisao                             [{'ADMINISTRACAO PUBLICA DEFESA E SEGURIDADE S...
# nm_segmento                            [{'ADMINISTRACAO PUBLICA DEFESA E SEGURIDADE S...
# fl_spa                                                          [{False: 539, True: 27}]
# fl_antt                                                         [{False: 474, True: 92}]
# fl_veiculo                                                      [{True: 490, False: 76}]
# fl_optante_simples                                              [{False: 539, True: 27}]
# vl_total_veiculos_pesados_grupo        [{0: 237, 1: 54, 2: 41, 3: 28, 4: 25, 5: 17, 7...
# vl_total_veiculos_leves_grupo          [{0: 118, 1: 56, 2: 49, 3: 43, 5: 39, 4: 34, 1...
# fl_optante_simei                                                          [{False: 566}]
# sg_uf_matriz                           [{'AM': 142, 'MA': 118, 'PI': 101, 'RN': 100, ...
# de_saude_tributaria                    [{'VERDE': 376, 'AZUL': 134, 'LARANJA': 44, 'V...
# de_saude_rescencia                                             [{'ACIMA DE 1 ANO': 566}]
# nu_meses_rescencia                     [{23: 410, 24: 64, 48: 29, 26: 24, 22: 18, 27:...
# de_nivel_atividade                              [{'ALTA': 523, 'MEDIA': 37, 'BAIXA': 6}]
# fl_simples_irregular                                             [{False: 565, True: 1}]
# fl_passivel_iss                                                 [{True: 490, False: 76}]
# de_faixa_faturamento_estimado          [{'DE R$ 10.000.000,01 A R$ 30.000.000,00': 27...
# de_faixa_faturamento_estimado_grupo    [{'DE R$ 10.000.000,01 A R$ 30.000.000,00': 24...
# vl_faturamento_estimado_aux            [{11024424: 5, 19266984: 5, 10715328: 3, 30497...
# vl_faturamento_estimado_grupo_aux      [{11024424: 5, 11745648: 3, 10921392: 3, 30497...
# qt_ex_funcionarios                     [{249: 5, 124: 5, 52: 5, 180: 4, 183: 4, 220: ...
# qt_funcionarios_grupo                  [{98: 7, 71: 7, 96: 7, 123: 6, 142: 6, 94: 6, ...
# percent_func_genero_masc               [{32: 14, 95: 14, 41: 13, 48: 13, 96: 12, 39: ...
# percent_func_genero_fem                [{68: 14, 5: 14, 52: 13, 59: 13, 4: 12, 20: 12...
# total                                  [{71: 9, 73: 7, 77: 7, 92: 6, 94: 6, 98: 6, 11...
# meses_ultima_contratacaco              [{2: 156, 3: 105, 4: 37, 23: 29, 24: 27, 5: 23...
# qt_admitidos_12meses                   [{0: 199, 10: 12, 6: 12, 4: 11, 14: 11, 16: 11...
# qt_desligados_12meses                  [{0: 187, 10: 16, 7: 15, 1: 13, 6: 11, 12: 11,...
# qt_desligados                          [{199: 5, 124: 5, 153: 4, 221: 4, 214: 4, 378:...
# qt_admitidos                           [{246: 5, 275: 4, 210: 4, 419: 4, 176: 3, 291:...
# media_meses_servicos_all               [{30: 18, 11: 14, 20: 14, 28: 13, 22: 13, 25: ...
# max_meses_servicos_all                 [{5015: 102, 5065: 18, 266: 7, 5099: 6, 255: 6...
# min_meses_servicos_all                 [{0: 240, -1: 145, 1: 49, 2: 19, 3: 15, -6: 8,...
# media_meses_servicos                   [{47: 12, 26: 12, 54: 10, 40: 10, 41: 9, 37: 9...
# max_meses_servicos                     [{266: 12, 507: 9, 5099: 6, 255: 6, 253: 6, 94...
# min_meses_servicos                     [{2: 156, 3: 103, 4: 38, 5: 24, 23: 23, 24: 20...
# qt_funcionarios                        [{71: 8, 80: 7, 73: 7, 131: 6, 81: 5, 85: 5, 7...
# qt_funcionarios_12meses                [{69: 9, 94: 7, 71: 7, 74: 7, 87: 6, 84: 6, 99...
# qt_funcionarios_24meses                [{68: 10, 81: 6, 95: 6, 99: 6, 73: 5, 94: 5, 9...
# tx_rotatividade                        [{0: 192, 11: 20, 13: 16, 8: 16, 20: 15, 18: 1...
# qt_filiais                             [{0: 270, 1: 108, 2: 49, 3: 29, 4: 18, 6: 18, ...
# dtype: object

# %% [markdown]
# >> ### Data visualization:

# %% [markdown]
# >> ### Graphs:

# %%
f, axes= plt.subplots(8, 3, figsize=(18, 45))

sns.countplot(data=portfolio_2_T2, x="fl_matriz", palette = 'gist_gray', order = portfolio_2_T2['fl_matriz'].value_counts().index, ax=axes[0,0]);
axes[0,0].set_title("fl_matriz")
axes[0,0].set_ylabel("")
axes[0,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="sg_uf", palette = 'gist_gray', order = portfolio_2_T2['sg_uf'].value_counts().index, ax=axes[0,1]);
axes[0,1].set_title("sg_uf")
axes[0,1].set_ylabel("")
axes[0,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="idade_emp_cat", palette = 'gist_gray', order = portfolio_2_T2['idade_emp_cat'].value_counts().index, ax=axes[0,2]);
axes[0,2].set_title("idade_emp_cat")
axes[0,2].set_ylabel("")
axes[0,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_me", palette = 'gist_gray', order = portfolio_2_T2['fl_me'].value_counts().index, ax=axes[1,0]);
axes[1,0].set_title("fl_me")
axes[1,0].set_ylabel("")
axes[1,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_sa", palette = 'gist_gray', order = portfolio_2_T2['fl_sa'].value_counts().index, ax=axes[1,1]);
axes[1,1].set_title("fl_sa")
axes[1,1].set_ylabel("")
axes[1,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_mei", palette = 'gist_gray', order = portfolio_2_T2['fl_mei'].value_counts().index, ax=axes[1,2]);
axes[1,2].set_title("fl_mei")
axes[1,2].set_ylabel("")
axes[1,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_ltda", palette = 'gist_gray', order = portfolio_2_T2['fl_ltda'].value_counts().index, ax=axes[2,0]);
axes[2,0].set_title("fl_ltda")
axes[2,0].set_ylabel("")
axes[2,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_st_especial", palette = 'gist_gray', order = portfolio_2_T2['fl_st_especial'].value_counts().index, ax=axes[2,1]);
axes[2,1].set_title("fl_st_especial")
axes[2,1].set_ylabel("")
axes[2,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_email", palette = 'gist_gray', order = portfolio_2_T2['fl_email'].value_counts().index, ax=axes[2,2]);
axes[2,2].set_title("fl_email")
axes[2,2].set_ylabel("")
axes[2,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_telefone", palette = 'gist_gray', order = portfolio_2_T2['fl_telefone'].value_counts().index, ax=axes[3,0]);
axes[3,0].set_title("fl_telefone")
axes[3,0].set_ylabel("")
axes[3,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_rm", palette = 'gist_gray', order = portfolio_2_T2['fl_rm'].value_counts().index, ax=axes[3,1]);
axes[3,1].set_title("fl_rm")
axes[3,1].set_ylabel("")
axes[3,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_epp", palette = 'gist_gray', order = portfolio_2_T2['fl_epp'].value_counts().index, ax=axes[3,2]);
axes[3,2].set_title("fl_epp")
axes[3,2].set_ylabel("")
axes[3,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_optante_simples", palette = 'gist_gray', order = portfolio_2_T2['fl_optante_simples'].value_counts().index, ax=axes[4,0]);
axes[4,0].set_title("fl_optante_simples")
axes[4,0].set_ylabel("")
axes[4,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="sg_uf_matriz", palette = 'gist_gray', order = portfolio_2_T2['sg_uf_matriz'].value_counts().index, ax=axes[4,1]);
plt.xticks(rotation=90)
axes[4,1].set_title("sg_uf_matriz")
axes[4,1].set_ylabel("")
axes[4,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_passivel_iss", palette = 'gist_gray', order = portfolio_2_T2['fl_passivel_iss'].value_counts().index, ax=axes[4,2]);
axes[4,2].set_title("fl_passivel_iss")
axes[4,2].set_ylabel("")
axes[4,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_spa", palette = 'gist_gray', order = portfolio_2_T2['fl_spa'].value_counts().index, ax=axes[5,0]);
axes[5,0].set_title("fl_spa")
axes[5,0].set_ylabel("")
axes[5,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_antt", palette = 'gist_gray', order = portfolio_2_T2['fl_antt'].value_counts().index, ax=axes[5,1]);
axes[5,1].set_title("fl_antt")
axes[5,1].set_ylabel("")
axes[5,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_veiculo", palette = 'gist_gray', order = portfolio_2_T2['fl_veiculo'].value_counts().index, ax=axes[5,2]);
axes[5,2].set_title("fl_veiculo")
axes[5,2].set_ylabel("")
axes[5,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="de_nivel_atividade", palette = 'gist_gray', order = portfolio_2_T2['de_nivel_atividade'].value_counts().index, ax=axes[6,0]);
axes[6,0].set_title("de_nivel_atividade")
axes[6,0].set_ylabel("")
axes[6,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_simples_irregular", palette = 'gist_gray', order = portfolio_2_T2['fl_simples_irregular'].value_counts().index, ax=axes[6,1]);
axes[6,1].set_title("fl_simples_irregular")
axes[6,1].set_ylabel("")
axes[6,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="fl_optante_simei", palette = 'gist_gray', order = portfolio_2_T2['fl_optante_simei'].value_counts().index, ax=axes[6,2]);
axes[6,2].set_title("fl_optante_simei")
axes[6,2].set_ylabel("")
axes[6,2].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="de_saude_tributaria", palette = 'gist_gray', order = portfolio_2_T2['de_saude_tributaria'].value_counts().index, ax=axes[7,0]);
axes[7,0].set_title("de_saude_tributaria")
axes[7,0].set_ylabel("")
axes[7,0].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="de_saude_rescencia", palette = 'gist_gray', order = portfolio_2_T2['de_saude_rescencia'].value_counts().index, ax=axes[7,1]);
axes[7,1].set_title("de_saude_rescencia")
axes[7,1].set_ylabel("")
axes[7,1].set_xlabel("")

sns.countplot(data=portfolio_2_T2, x="setor", palette = 'gist_gray', order = portfolio_2_T2['setor'].value_counts().index, ax=axes[7,2]);
axes[7,2].set_title("setor")
axes[7,2].set_ylabel("")
axes[7,2].set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="qt_filiais", palette = 'gist_gray', order = portfolio_2_T2['qt_filiais'].value_counts().index);
ax.set_title("qt_filiais")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="de_faixa_faturamento_estimado", palette = 'gist_gray', order = portfolio_2_T2['de_faixa_faturamento_estimado'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_faixa_faturamento_estimado")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="natureza_juridica_macro", palette = 'gist_gray', order = portfolio_2_T2['natureza_juridica_macro'].value_counts().index);
ax.set_title("natureza_juridica_macro")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="nm_divisao", palette = 'gist_gray', order = portfolio_2_T2['nm_divisao'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_divisao")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="nm_segmento", palette = 'gist_gray', order = portfolio_2_T2['nm_segmento'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_segmento")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="de_natureza_juridica", palette = 'gist_gray', order = portfolio_2_T2['de_natureza_juridica'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_natureza_juridica")
ax.set_ylabel("")
ax.set_xlabel("")


fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="de_ramo", palette = 'gist_gray', order = portfolio_2_T2['de_ramo'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_ramo")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_2_T2, x="idade_empresa_anos", palette = 'gist_gray', order = portfolio_2_T2['idade_empresa_anos'].value_counts().index);
ax.set_title("idade_empresa_anos")
ax.set_ylabel("")
ax.set_xlabel("")

plt.show()

# %% [markdown]
# >> ### Correlations:

# %%
# Convert object columns to numeric value
portfolio_2_T2['de_natureza_juridica'] = pd.factorize(portfolio_2_T2['de_natureza_juridica'])[0]
portfolio_2_T2['sg_uf'] = pd.factorize(portfolio_2_T2['sg_uf'])[0]
portfolio_2_T2['natureza_juridica_macro'] = pd.factorize(portfolio_2_T2['natureza_juridica_macro'])[0]
portfolio_2_T2['de_ramo'] = pd.factorize(portfolio_2_T2['de_ramo'])[0]
portfolio_2_T2['setor'] = pd.factorize(portfolio_2_T2['setor'])[0]
portfolio_2_T2['idade_emp_cat'] = pd.factorize(portfolio_2_T2['idade_emp_cat'])[0]
portfolio_2_T2['dt_situacao'] = pd.factorize(portfolio_2_T2['dt_situacao'])[0]
portfolio_2_T2['fl_rm'] = pd.factorize(portfolio_2_T2['fl_rm'])[0]
portfolio_2_T2['nm_divisao'] = pd.factorize(portfolio_2_T2['nm_divisao'])[0]
portfolio_2_T2['nm_segmento'] = pd.factorize(portfolio_2_T2['nm_segmento'])[0]
portfolio_2_T2['sg_uf_matriz'] = pd.factorize(portfolio_2_T2['sg_uf_matriz'])[0]
portfolio_2_T2['fl_spa'] = pd.factorize(portfolio_2_T2['fl_spa'])[0]
portfolio_2_T2['fl_antt'] = pd.factorize(portfolio_2_T2['fl_antt'])[0]
portfolio_2_T2['fl_veiculo'] = pd.factorize(portfolio_2_T2['fl_veiculo'])[0]
portfolio_2_T2['fl_optante_simples'] = pd.factorize(portfolio_2_T2['fl_optante_simples'])[0]
portfolio_2_T2['fl_optante_simei'] = pd.factorize(portfolio_2_T2['fl_optante_simei'])[0]
portfolio_2_T2['de_saude_tributaria'] = pd.factorize(portfolio_2_T2['de_saude_tributaria'])[0]
portfolio_2_T2['de_saude_rescencia'] = pd.factorize(portfolio_2_T2['de_saude_rescencia'])[0]
portfolio_2_T2['de_nivel_atividade'] = pd.factorize(portfolio_2_T2['de_nivel_atividade'])[0]
portfolio_2_T2['fl_simples_irregular'] = pd.factorize(portfolio_2_T2['fl_simples_irregular'])[0]
portfolio_2_T2['fl_passivel_iss'] = pd.factorize(portfolio_2_T2['fl_passivel_iss'])[0]
portfolio_2_T2['de_faixa_faturamento_estimado'] = pd.factorize(portfolio_2_T2['de_faixa_faturamento_estimado'])[0]
portfolio_2_T2['de_faixa_faturamento_estimado_grupo'] = pd.factorize(portfolio_2_T2['de_faixa_faturamento_estimado_grupo'])[0]

# %%
correlation = portfolio_2_T2.corr(method="pearson")
correlation
# Out:
#                                      fl_matriz  de_natureza_juridica  \
# fl_matriz                                  NaN                   NaN
# de_natureza_juridica                       NaN              1.000000
# sg_uf                                      NaN              0.000691
# natureza_juridica_macro                    NaN             -0.085463
# de_ramo                                    NaN              0.151180
# setor                                      NaN             -0.088528
# idade_empresa_anos                         NaN             -0.089550
# idade_emp_cat                              NaN              0.065163
# fl_me                                      NaN             -0.047595
# fl_sa                                      NaN              0.244689
# fl_epp                                     NaN                   NaN
# fl_mei                                     NaN                   NaN
# fl_ltda                                    NaN             -0.042826
# dt_situacao                                NaN              0.159027
# fl_st_especial                             NaN              0.098283
# fl_email                                   NaN              0.063193
# fl_telefone                                NaN              0.048221
# fl_rm                                      NaN              0.149161
# nm_divisao                                 NaN              0.111917
# nm_segmento                                NaN              0.173803
# fl_spa                                     NaN             -0.016432
# fl_antt                                    NaN             -0.080634
# fl_veiculo                                 NaN              0.162777
# fl_optante_simples                         NaN              0.008710
# vl_total_veiculos_pesados_grupo            NaN             -0.066098
# vl_total_veiculos_leves_grupo              NaN              0.045866
# fl_optante_simei                           NaN                   NaN
# sg_uf_matriz                               NaN              0.000691
# de_saude_tributaria                        NaN              0.068743
# de_saude_rescencia                         NaN                   NaN
# nu_meses_rescencia                         NaN              0.024770
# de_nivel_atividade                         NaN              0.116026
# fl_simples_irregular                       NaN             -0.013995
# fl_passivel_iss                            NaN              0.003191
# de_faixa_faturamento_estimado              NaN              0.010142
# de_faixa_faturamento_estimado_grupo        NaN             -0.004117
# vl_faturamento_estimado_aux                NaN              0.119046
# vl_faturamento_estimado_grupo_aux          NaN              0.111842
# qt_ex_funcionarios                         NaN             -0.019410
# qt_funcionarios_grupo                      NaN              0.035964
# percent_func_genero_masc                   NaN             -0.021973
# percent_func_genero_fem                    NaN              0.021973
# total                                      NaN              0.004910
# meses_ultima_contratacaco                  NaN              0.125552
# qt_admitidos_12meses                       NaN             -0.025949
# qt_desligados_12meses                      NaN             -0.023138
# qt_desligados                              NaN             -0.019542
# qt_admitidos                               NaN             -0.010208
# media_meses_servicos_all                   NaN              0.088944
# max_meses_servicos_all                     NaN             -0.033812
# min_meses_servicos_all                     NaN              0.184925
# media_meses_servicos                       NaN              0.069103
# max_meses_servicos                         NaN              0.000406
# min_meses_servicos                         NaN              0.128441
# qt_funcionarios                            NaN              0.004632
# qt_funcionarios_12meses                    NaN              0.004632
# qt_funcionarios_24meses                    NaN             -0.008666
# tx_rotatividade                            NaN             -0.020189
# qt_filiais                                 NaN              0.116855
#
#                                         sg_uf  natureza_juridica_macro  \
# fl_matriz                                 NaN                      NaN
# de_natureza_juridica                 0.000691                -0.085463
# sg_uf                                1.000000                 0.080434
# natureza_juridica_macro              0.080434                 1.000000
# de_ramo                              0.048256                 0.478657
# setor                                0.064684                 0.331656
# idade_empresa_anos                  -0.046753                -0.132628
# idade_emp_cat                       -0.079109                 0.001471
# fl_me                                0.006837                -0.047277
# fl_sa                                0.023629                 0.087167
# fl_epp                                    NaN                      NaN
# fl_mei                                    NaN                      NaN
# fl_ltda                              0.023392                 0.045513
# dt_situacao                         -0.030074                -0.055972
# fl_st_especial                       0.064882                -0.007575
# fl_email                             0.016785                 0.132307
# fl_telefone                          0.067385                 0.161769
# fl_rm                                0.071994                 0.332000
# nm_divisao                           0.063951                 0.387603
# nm_segmento                          0.065870                 0.539872
# fl_spa                               0.058017                 0.109690
# fl_antt                              0.000792                 0.161051
# fl_veiculo                           0.014909                -0.119197
# fl_optante_simples                  -0.028171                 0.032319
# vl_total_veiculos_pesados_grupo      0.064299                 0.074094
# vl_total_veiculos_leves_grupo        0.074206                -0.038579
# fl_optante_simei                          NaN                      NaN
# sg_uf_matriz                         1.000000                 0.080434
# de_saude_tributaria                 -0.087748                -0.202364
# de_saude_rescencia                        NaN                      NaN
# nu_meses_rescencia                  -0.061644                -0.076689
# de_nivel_atividade                  -0.004868                -0.321194
# fl_simples_irregular                 0.004830                 0.022696
# fl_passivel_iss                      0.011542                 0.157187
# de_faixa_faturamento_estimado       -0.006859                 0.063469
# de_faixa_faturamento_estimado_grupo  0.011974                 0.025949
# vl_faturamento_estimado_aux          0.030926                -0.224300
# vl_faturamento_estimado_grupo_aux    0.064118                -0.127560
# qt_ex_funcionarios                   0.053017                 0.086249
# qt_funcionarios_grupo                0.069368                -0.017611
# percent_func_genero_masc            -0.001831                 0.265245
# percent_func_genero_fem              0.001831                -0.265245
# total                                0.041678                -0.195708
# meses_ultima_contratacaco           -0.003930                -0.441794
# qt_admitidos_12meses                 0.072295                 0.178378
# qt_desligados_12meses                0.074950                 0.168561
# qt_desligados                        0.053030                 0.086291
# qt_admitidos                         0.058387                -0.053250
# media_meses_servicos_all            -0.085525                -0.540437
# max_meses_servicos_all              -0.071355                -0.376329
# min_meses_servicos_all               0.065908                -0.134149
# media_meses_servicos                -0.115133                -0.582476
# max_meses_servicos                  -0.026719                -0.065813
# min_meses_servicos                  -0.006771                -0.441920
# qt_funcionarios                      0.041888                -0.194932
# qt_funcionarios_12meses              0.040921                -0.196837
# qt_funcionarios_24meses              0.031407                -0.188919
# tx_rotatividade                      0.034146                 0.324624
# qt_filiais                           0.007736                 0.090397
#
#                                       de_ramo     setor  idade_empresa_anos  \
# fl_matriz                                 NaN       NaN                 NaN
# de_natureza_juridica                 0.151180 -0.088528           -0.089550
# sg_uf                                0.048256  0.064684           -0.046753
# natureza_juridica_macro              0.478657  0.331656           -0.132628
# de_ramo                              1.000000  0.448587           -0.139874
# setor                                0.448587  1.000000           -0.182270
# idade_empresa_anos                  -0.139874 -0.182270            1.000000
# idade_emp_cat                       -0.037222 -0.030935            0.152780
# fl_me                               -0.056916 -0.045220            0.030595
# fl_sa                                0.214406  0.158165            0.008083
# fl_epp                                    NaN       NaN                 NaN
# fl_mei                                    NaN       NaN                 NaN
# fl_ltda                             -0.019218 -0.064064           -0.027340
# dt_situacao                         -0.014162 -0.029444           -0.294033
# fl_st_especial                       0.044236 -0.045220            0.030595
# fl_email                             0.115257  0.145103           -0.276036
# fl_telefone                          0.140675  0.179820           -0.323187
# fl_rm                                0.342620  0.208579           -0.123578
# nm_divisao                           0.813950  0.443338           -0.127465
# nm_segmento                          0.897147  0.291224           -0.145898
# fl_spa                               0.106584  0.110138            0.003154
# fl_antt                              0.138244  0.247960           -0.055121
# fl_veiculo                           0.006692 -0.088947           -0.155682
# fl_optante_simples                   0.011373  0.031711           -0.086600
# vl_total_veiculos_pesados_grupo      0.087354 -0.003228            0.050313
# vl_total_veiculos_leves_grupo        0.014221  0.052393            0.061455
# fl_optante_simei                          NaN       NaN                 NaN
# sg_uf_matriz                         0.048256  0.064684           -0.046753
# de_saude_tributaria                 -0.154669 -0.185024            0.170528
# de_saude_rescencia                        NaN       NaN                 NaN
# nu_meses_rescencia                  -0.053749 -0.043517            0.027656
# de_nivel_atividade                  -0.211654 -0.200059           -0.061387
# fl_simples_irregular                -0.012986  0.024915           -0.032614
# fl_passivel_iss                      0.196987  0.471362           -0.061724
# de_faixa_faturamento_estimado        0.119870  0.071593           -0.083218
# de_faixa_faturamento_estimado_grupo  0.084231  0.053882           -0.070619
# vl_faturamento_estimado_aux         -0.104094 -0.083681            0.114926
# vl_faturamento_estimado_grupo_aux   -0.070223 -0.035767            0.060302
# qt_ex_funcionarios                  -0.006820  0.067316           -0.050255
# qt_funcionarios_grupo               -0.035337 -0.004876           -0.017448
# percent_func_genero_masc             0.308508  0.531654           -0.227567
# percent_func_genero_fem             -0.308508 -0.531654            0.227567
# total                               -0.137810 -0.129988            0.124725
# meses_ultima_contratacaco           -0.292559 -0.267331            0.122224
# qt_admitidos_12meses                 0.118730  0.205410           -0.089814
# qt_desligados_12meses                0.084027  0.118338           -0.143819
# qt_desligados                       -0.006855  0.067490           -0.050190
# qt_admitidos                        -0.081777 -0.028378            0.037115
# media_meses_servicos_all            -0.385519 -0.390181            0.363972
# max_meses_servicos_all              -0.374534 -0.302520            0.289567
# min_meses_servicos_all              -0.070460 -0.082279           -0.016570
# media_meses_servicos                -0.401226 -0.440094            0.450378
# max_meses_servicos                  -0.089133 -0.103676            0.179888
# min_meses_servicos                  -0.275332 -0.266336            0.124099
# qt_funcionarios                     -0.137138 -0.128912            0.124280
# qt_funcionarios_12meses             -0.140904 -0.136706            0.121620
# qt_funcionarios_24meses             -0.156039 -0.145092            0.124800
# tx_rotatividade                      0.187314  0.317138           -0.277532
# qt_filiais                           0.103017  0.038227            0.087694
#
#                                      idade_emp_cat     fl_me     fl_sa  ...  \
# fl_matriz                                      NaN       NaN       NaN  ...
# de_natureza_juridica                      0.065163 -0.047595  0.244689  ...
# sg_uf                                    -0.079109  0.006837  0.023629  ...
# natureza_juridica_macro                   0.001471 -0.047277  0.087167  ...
# de_ramo                                  -0.037222 -0.056916  0.214406  ...
# setor                                    -0.030935 -0.045220  0.158165  ...
# idade_empresa_anos                        0.152780  0.030595  0.008083  ...
# idade_emp_cat                             1.000000  0.001648 -0.103320  ...
# fl_me                                     0.001648  1.000000 -0.012256  ...
# fl_sa                                    -0.103320 -0.012256  1.000000  ...
# fl_epp                                         NaN       NaN       NaN  ...
# fl_mei                                         NaN       NaN       NaN  ...
# fl_ltda                                   0.002335 -0.005024 -0.017363  ...
# dt_situacao                              -0.210509 -0.014537  0.051697  ...
# fl_st_especial                            0.001648 -0.003546 -0.012256  ...
# fl_email                                 -0.085312 -0.055283 -0.011605  ...
# fl_telefone                              -0.099485 -0.064833  0.045347  ...
# fl_rm                                    -0.019247 -0.064833  0.117192  ...
# nm_divisao                                0.002697 -0.048275  0.202699  ...
# nm_segmento                              -0.055884 -0.063164  0.199580  ...
# fl_spa                                    0.020621 -0.013328  0.079887  ...
# fl_antt                                   0.003858 -0.026235 -0.042165  ...
# fl_veiculo                               -0.043214 -0.023452  0.050172  ...
# fl_optante_simples                       -0.051514 -0.013328 -0.046063  ...
# vl_total_veiculos_pesados_grupo           0.015584 -0.011977 -0.006410  ...
# vl_total_veiculos_leves_grupo             0.036266 -0.013771 -0.037715  ...
# fl_optante_simei                               NaN       NaN       NaN  ...
# sg_uf_matriz                             -0.079109  0.006837  0.023629  ...
# de_saude_tributaria                      -0.012041  0.003431  0.017940  ...
# de_saude_rescencia                             NaN       NaN       NaN  ...
# nu_meses_rescencia                       -0.018824 -0.017636  0.023723  ...
# de_nivel_atividade                        0.007566 -0.016280 -0.056265  ...
# fl_simples_irregular                      0.074384 -0.002505 -0.008658  ...
# fl_passivel_iss                          -0.016157 -0.023452  0.155152  ...
# de_faixa_faturamento_estimado            -0.025166 -0.019173  0.021881  ...
# de_faixa_faturamento_estimado_grupo      -0.009518 -0.017979  0.083494  ...
# vl_faturamento_estimado_aux              -0.010676  0.003916  0.069811  ...
# vl_faturamento_estimado_grupo_aux        -0.057495 -0.000838  0.181102  ...
# qt_ex_funcionarios                       -0.055863 -0.010021  0.024478  ...
# qt_funcionarios_grupo                    -0.072872 -0.000630  0.200030  ...
# percent_func_genero_masc                 -0.025054 -0.044998  0.058136  ...
# percent_func_genero_fem                   0.025054  0.044998 -0.058136  ...
# total                                    -0.006180  0.010265  0.002702  ...
# meses_ultima_contratacaco                -0.054935  0.033442 -0.004477  ...
# qt_admitidos_12meses                     -0.059281 -0.023898  0.102738  ...
# qt_desligados_12meses                    -0.056086 -0.023957  0.078468  ...
# qt_desligados                            -0.055866 -0.009983  0.024499  ...
# qt_admitidos                             -0.040316 -0.000821  0.017650  ...
# media_meses_servicos_all                  0.072633  0.039211 -0.037457  ...
# max_meses_servicos_all                    0.065155  0.104335 -0.088224  ...
# min_meses_servicos_all                   -0.057662  0.000738 -0.005569  ...
# media_meses_servicos                      0.096934  0.093207 -0.011855  ...
# max_meses_servicos                       -0.013696  0.005804 -0.022522  ...
# min_meses_servicos                       -0.057564  0.031381  0.001674  ...
# qt_funcionarios                          -0.006520  0.010163  0.002806  ...
# qt_funcionarios_12meses                  -0.006104  0.010315 -0.000234  ...
# qt_funcionarios_24meses                  -0.016238  0.014313  0.000568  ...
# tx_rotatividade                          -0.073480 -0.044981  0.034991  ...
# qt_filiais                               -0.013581 -0.017343  0.132027  ...
#
#                                      max_meses_servicos_all  \
# fl_matriz                                               NaN
# de_natureza_juridica                              -0.033812
# sg_uf                                             -0.071355
# natureza_juridica_macro                           -0.376329
# de_ramo                                           -0.374534
# setor                                             -0.302520
# idade_empresa_anos                                 0.289567
# idade_emp_cat                                      0.065155
# fl_me                                              0.104335
# fl_sa                                             -0.088224
# fl_epp                                                  NaN
# fl_mei                                                  NaN
# fl_ltda                                           -0.049130
# dt_situacao                                       -0.014979
# fl_st_especial                                    -0.032277
# fl_email                                          -0.176733
# fl_telefone                                       -0.245363
# fl_rm                                             -0.197157
# nm_divisao                                        -0.299666
# nm_segmento                                       -0.381928
# fl_spa                                            -0.009190
# fl_antt                                           -0.151803
# fl_veiculo                                        -0.031195
# fl_optante_simples                                -0.116305
# vl_total_veiculos_pesados_grupo                   -0.045639
# vl_total_veiculos_leves_grupo                     -0.021185
# fl_optante_simei                                        NaN
# sg_uf_matriz                                      -0.071355
# de_saude_tributaria                                0.131329
# de_saude_rescencia                                      NaN
# nu_meses_rescencia                                 0.033314
# de_nivel_atividade                                 0.086921
# fl_simples_irregular                              -0.025673
# fl_passivel_iss                                   -0.141059
# de_faixa_faturamento_estimado                     -0.048126
# de_faixa_faturamento_estimado_grupo               -0.022284
# vl_faturamento_estimado_aux                        0.173311
# vl_faturamento_estimado_grupo_aux                  0.104400
# qt_ex_funcionarios                                -0.022064
# qt_funcionarios_grupo                              0.024338
# percent_func_genero_masc                          -0.273146
# percent_func_genero_fem                            0.273146
# total                                              0.212848
# meses_ultima_contratacaco                          0.312024
# qt_admitidos_12meses                              -0.076002
# qt_desligados_12meses                             -0.123943
# qt_desligados                                     -0.021943
# qt_admitidos                                       0.105482
# media_meses_servicos_all                           0.579361
# max_meses_servicos_all                             1.000000
# min_meses_servicos_all                             0.099448
# media_meses_servicos                               0.500689
# max_meses_servicos                                 0.336761
# min_meses_servicos                                 0.301961
# qt_funcionarios                                    0.212723
# qt_funcionarios_12meses                            0.210412
# qt_funcionarios_24meses                            0.206574
# tx_rotatividade                                   -0.245374
# qt_filiais                                        -0.010607
#
#                                      min_meses_servicos_all  \
# fl_matriz                                               NaN
# de_natureza_juridica                               0.184925
# sg_uf                                              0.065908
# natureza_juridica_macro                           -0.134149
# de_ramo                                           -0.070460
# setor                                             -0.082279
# idade_empresa_anos                                -0.016570
# idade_emp_cat                                     -0.057662
# fl_me                                              0.000738
# fl_sa                                             -0.005569
# fl_epp                                                  NaN
# fl_mei                                                  NaN
# fl_ltda                                            0.006264
# dt_situacao                                        0.051490
# fl_st_especial                                     0.079324
# fl_email                                          -0.074424
# fl_telefone                                       -0.049988
# fl_rm                                             -0.093278
# nm_divisao                                        -0.065287
# nm_segmento                                       -0.076532
# fl_spa                                            -0.026627
# fl_antt                                           -0.058529
# fl_veiculo                                         0.117715
# fl_optante_simples                                -0.012953
# vl_total_veiculos_pesados_grupo                   -0.035019
# vl_total_veiculos_leves_grupo                     -0.056281
# fl_optante_simei                                        NaN
# sg_uf_matriz                                       0.065908
# de_saude_tributaria                                0.204549
# de_saude_rescencia                                      NaN
# nu_meses_rescencia                                -0.034008
# de_nivel_atividade                                 0.175034
# fl_simples_irregular                              -0.002949
# fl_passivel_iss                                   -0.031024
# de_faixa_faturamento_estimado                     -0.026696
# de_faixa_faturamento_estimado_grupo               -0.024551
# vl_faturamento_estimado_aux                       -0.051480
# vl_faturamento_estimado_grupo_aux                 -0.046005
# qt_ex_funcionarios                                -0.025023
# qt_funcionarios_grupo                             -0.022444
# percent_func_genero_masc                          -0.096885
# percent_func_genero_fem                            0.096885
# total                                             -0.062640
# meses_ultima_contratacaco                          0.789900
# qt_admitidos_12meses                              -0.046100
# qt_desligados_12meses                             -0.046389
# qt_desligados                                     -0.025133
# qt_admitidos                                      -0.051848
# media_meses_servicos_all                           0.498021
# max_meses_servicos_all                             0.099448
# min_meses_servicos_all                             1.000000
# media_meses_servicos                               0.304969
# max_meses_servicos                                 0.025156
# min_meses_servicos                                 0.756477
# qt_funcionarios                                   -0.062753
# qt_funcionarios_12meses                           -0.062509
# qt_funcionarios_24meses                           -0.075257
# tx_rotatividade                                   -0.075909
# qt_filiais                                        -0.044077
#
#                                      media_meses_servicos  max_meses_servicos  \
# fl_matriz                                             NaN                 NaN
# de_natureza_juridica                             0.069103            0.000406
# sg_uf                                           -0.115133           -0.026719
# natureza_juridica_macro                         -0.582476           -0.065813
# de_ramo                                         -0.401226           -0.089133
# setor                                           -0.440094           -0.103676
# idade_empresa_anos                               0.450378            0.179888
# idade_emp_cat                                    0.096934           -0.013696
# fl_me                                            0.093207            0.005804
# fl_sa                                           -0.011855           -0.022522
# fl_epp                                                NaN                 NaN
# fl_mei                                                NaN                 NaN
# fl_ltda                                         -0.017209           -0.018565
# dt_situacao                                      0.018040            0.039880
# fl_st_especial                                   0.013191           -0.003607
# fl_email                                        -0.262476           -0.025916
# fl_telefone                                     -0.296389           -0.048181
# fl_rm                                           -0.283418            0.026599
# nm_divisao                                      -0.337208           -0.054473
# nm_segmento                                     -0.449446           -0.076015
# fl_spa                                          -0.095096            0.035041
# fl_antt                                         -0.229852           -0.044989
# fl_veiculo                                       0.038501            0.040730
# fl_optante_simples                              -0.147570           -0.074874
# vl_total_veiculos_pesados_grupo                 -0.063027           -0.023112
# vl_total_veiculos_leves_grupo                    0.006694           -0.022246
# fl_optante_simei                                      NaN                 NaN
# sg_uf_matriz                                    -0.115133           -0.026719
# de_saude_tributaria                              0.307128            0.077881
# de_saude_rescencia                                    NaN                 NaN
# nu_meses_rescencia                              -0.004458            0.049683
# de_nivel_atividade                               0.277719            0.030741
# fl_simples_irregular                            -0.034020           -0.013900
# fl_passivel_iss                                 -0.177351            0.016941
# de_faixa_faturamento_estimado                   -0.017898            0.079409
# de_faixa_faturamento_estimado_grupo             -0.016034            0.029841
# vl_faturamento_estimado_aux                      0.171977            0.074112
# vl_faturamento_estimado_grupo_aux                0.089945            0.043900
# qt_ex_funcionarios                              -0.125684            0.030549
# qt_funcionarios_grupo                           -0.004418            0.001127
# percent_func_genero_masc                        -0.430248           -0.121531
# percent_func_genero_fem                          0.430248            0.121531
# total                                            0.158078            0.083713
# meses_ultima_contratacaco                        0.598324            0.079993
# qt_admitidos_12meses                            -0.317081           -0.021059
# qt_desligados_12meses                           -0.293142           -0.033141
# qt_desligados                                   -0.125875            0.030637
# qt_admitidos                                     0.005894            0.067289
# media_meses_servicos_all                         0.850871            0.195086
# max_meses_servicos_all                           0.500689            0.336761
# min_meses_servicos_all                           0.304969            0.025156
# media_meses_servicos                             1.000000            0.276305
# max_meses_servicos                               0.276305            1.000000
# min_meses_servicos                               0.604077            0.078911
# qt_funcionarios                                  0.156970            0.083750
# qt_funcionarios_12meses                          0.161156            0.082759
# qt_funcionarios_24meses                          0.160271            0.088626
# tx_rotatividade                                 -0.528590           -0.122240
# qt_filiais                                      -0.021730            0.006458
#
#                                      min_meses_servicos  qt_funcionarios  \
# fl_matriz                                           NaN              NaN
# de_natureza_juridica                           0.128441         0.004632
# sg_uf                                         -0.006771         0.041888
# natureza_juridica_macro                       -0.441920        -0.194932
# de_ramo                                       -0.275332        -0.137138
# setor                                         -0.266336        -0.128912
# idade_empresa_anos                             0.124099         0.124280
# idade_emp_cat                                 -0.057564        -0.006520
# fl_me                                          0.031381         0.010163
# fl_sa                                          0.001674         0.002806
# fl_epp                                              NaN              NaN
# fl_mei                                              NaN              NaN
# fl_ltda                                       -0.024909        -0.022413
# dt_situacao                                    0.083157        -0.038433
# fl_st_especial                                 0.012854        -0.014270
# fl_email                                      -0.143701        -0.088361
# fl_telefone                                   -0.168086        -0.104438
# fl_rm                                         -0.270220         0.001082
# nm_divisao                                    -0.229481        -0.098297
# nm_segmento                                   -0.301248        -0.150624
# fl_spa                                        -0.069028         0.007683
# fl_antt                                       -0.156891        -0.057355
# fl_veiculo                                     0.135220        -0.050273
# fl_optante_simples                            -0.083396        -0.061465
# vl_total_veiculos_pesados_grupo               -0.076275         0.026134
# vl_total_veiculos_leves_grupo                 -0.052760         0.199002
# fl_optante_simei                                    NaN              NaN
# sg_uf_matriz                                  -0.006771         0.041888
# de_saude_tributaria                            0.341411         0.055934
# de_saude_rescencia                                  NaN              NaN
# nu_meses_rescencia                             0.003172        -0.014491
# de_nivel_atividade                             0.326942         0.016500
# fl_simples_irregular                          -0.018031        -0.013581
# fl_passivel_iss                               -0.129405        -0.087745
# de_faixa_faturamento_estimado                 -0.060545         0.055938
# de_faixa_faturamento_estimado_grupo           -0.045600         0.089557
# vl_faturamento_estimado_aux                    0.048223         0.889102
# vl_faturamento_estimado_grupo_aux              0.007647         0.677587
# qt_ex_funcionarios                             0.012830         0.341014
# qt_funcionarios_grupo                         -0.016429         0.267022
# percent_func_genero_masc                      -0.243972        -0.144434
# percent_func_genero_fem                        0.243972         0.144434
# total                                          0.039904         0.999989
# meses_ultima_contratacaco                      0.983331         0.044364
# qt_admitidos_12meses                          -0.199557         0.153799
# qt_desligados_12meses                         -0.189262         0.113474
# qt_desligados                                  0.012607         0.341214
# qt_admitidos                                   0.030381         0.787325
# media_meses_servicos_all                       0.669246         0.134125
# max_meses_servicos_all                         0.301961         0.212723
# min_meses_servicos_all                         0.756477        -0.062753
# media_meses_servicos                           0.604077         0.156970
# max_meses_servicos                             0.078911         0.083750
# min_meses_servicos                             1.000000         0.039239
# qt_funcionarios                                0.039239         1.000000
# qt_funcionarios_12meses                        0.041395         0.997605
# qt_funcionarios_24meses                        0.037918         0.978285
# tx_rotatividade                               -0.336245        -0.115292
# qt_filiais                                    -0.082119         0.414844
#
#                                      qt_funcionarios_12meses  \
# fl_matriz                                                NaN
# de_natureza_juridica                                0.004632
# sg_uf                                               0.040921
# natureza_juridica_macro                            -0.196837
# de_ramo                                            -0.140904
# setor                                              -0.136706
# idade_empresa_anos                                  0.121620
# idade_emp_cat                                      -0.006104
# fl_me                                               0.010315
# fl_sa                                              -0.000234
# fl_epp                                                   NaN
# fl_mei                                                   NaN
# fl_ltda                                            -0.023658
# dt_situacao                                        -0.039465
# fl_st_especial                                     -0.014268
# fl_email                                           -0.085025
# fl_telefone                                        -0.102396
# fl_rm                                              -0.000262
# nm_divisao                                         -0.104596
# nm_segmento                                        -0.154817
# fl_spa                                              0.001009
# fl_antt                                            -0.060824
# fl_veiculo                                         -0.051311
# fl_optante_simples                                 -0.060554
# vl_total_veiculos_pesados_grupo                     0.024290
# vl_total_veiculos_leves_grupo                       0.196781
# fl_optante_simei                                         NaN
# sg_uf_matriz                                        0.040921
# de_saude_tributaria                                 0.058546
# de_saude_rescencia                                       NaN
# nu_meses_rescencia                                 -0.016246
# de_nivel_atividade                                  0.017569
# fl_simples_irregular                               -0.013386
# fl_passivel_iss                                    -0.087866
# de_faixa_faturamento_estimado                       0.049402
# de_faixa_faturamento_estimado_grupo                 0.080904
# vl_faturamento_estimado_aux                         0.885633
# vl_faturamento_estimado_grupo_aux                   0.669699
# qt_ex_funcionarios                                  0.349433
# qt_funcionarios_grupo                               0.258722
# percent_func_genero_masc                           -0.150434
# percent_func_genero_fem                             0.150434
# total                                               0.997702
# meses_ultima_contratacaco                           0.046431
# qt_admitidos_12meses                                0.124298
# qt_desligados_12meses                               0.142666
# qt_desligados                                       0.349607
# qt_admitidos                                        0.791480
# media_meses_servicos_all                            0.136800
# max_meses_servicos_all                              0.210412
# min_meses_servicos_all                             -0.062509
# media_meses_servicos                                0.161156
# max_meses_servicos                                  0.082759
# min_meses_servicos                                  0.041395
# qt_funcionarios                                     0.997605
# qt_funcionarios_12meses                             1.000000
# qt_funcionarios_24meses                             0.983338
# tx_rotatividade                                    -0.100736
# qt_filiais                                          0.411015
#
#                                      qt_funcionarios_24meses  tx_rotatividade  \
# fl_matriz                                                NaN              NaN
# de_natureza_juridica                               -0.008666        -0.020189
# sg_uf                                               0.031407         0.034146
# natureza_juridica_macro                            -0.188919         0.324624
# de_ramo                                            -0.156039         0.187314
# setor                                              -0.145092         0.317138
# idade_empresa_anos                                  0.124800        -0.277532
# idade_emp_cat                                      -0.016238        -0.073480
# fl_me                                               0.014313        -0.044981
# fl_sa                                               0.000568         0.034991
# fl_epp                                                   NaN              NaN
# fl_mei                                                   NaN              NaN
# fl_ltda                                            -0.026642        -0.022183
# dt_situacao                                        -0.040202         0.022821
# fl_st_especial                                     -0.017236         0.021811
# fl_email                                           -0.075600         0.195793
# fl_telefone                                        -0.096030         0.194940
# fl_rm                                               0.008269         0.123729
# nm_divisao                                         -0.113947         0.171320
# nm_segmento                                        -0.167245         0.214258
# fl_spa                                              0.001221         0.064062
# fl_antt                                            -0.054746         0.174728
# fl_veiculo                                         -0.048891        -0.053935
# fl_optante_simples                                 -0.066219         0.071319
# vl_total_veiculos_pesados_grupo                     0.025623         0.040784
# vl_total_veiculos_leves_grupo                       0.195830        -0.008387
# fl_optante_simei                                         NaN              NaN
# sg_uf_matriz                                        0.031407         0.034146
# de_saude_tributaria                                 0.072399        -0.214085
# de_saude_rescencia                                       NaN              NaN
# nu_meses_rescencia                                 -0.020359        -0.000624
# de_nivel_atividade                                  0.007442        -0.189715
# fl_simples_irregular                               -0.015160        -0.001854
# fl_passivel_iss                                    -0.098076         0.118732
# de_faixa_faturamento_estimado                       0.025339         0.001519
# de_faixa_faturamento_estimado_grupo                 0.059346        -0.001060
# vl_faturamento_estimado_aux                         0.860864        -0.119880
# vl_faturamento_estimado_grupo_aux                   0.653751        -0.048470
# qt_ex_funcionarios                                  0.443567         0.107410
# qt_funcionarios_grupo                               0.257178         0.030606
# percent_func_genero_masc                           -0.146241         0.312150
# percent_func_genero_fem                             0.146241        -0.312150
# total                                               0.978434        -0.116068
# meses_ultima_contratacaco                           0.043076        -0.334006
# qt_admitidos_12meses                                0.115948         0.313634
# qt_desligados_12meses                               0.166465         0.523940
# qt_desligados                                       0.443705         0.107694
# qt_admitidos                                        0.842312         0.005668
# media_meses_servicos_all                            0.120166        -0.408665
# max_meses_servicos_all                              0.206574        -0.245374
# min_meses_servicos_all                             -0.075257        -0.075909
# media_meses_servicos                                0.160271        -0.528590
# max_meses_servicos                                  0.088626        -0.122240
# min_meses_servicos                                  0.037918        -0.336245
# qt_funcionarios                                     0.978285        -0.115292
# qt_funcionarios_12meses                             0.983338        -0.100736
# qt_funcionarios_24meses                             1.000000        -0.106997
# tx_rotatividade                                    -0.106997         1.000000
# qt_filiais                                          0.401339         0.015187
#
#                                      qt_filiais
# fl_matriz                                   NaN
# de_natureza_juridica                   0.116855
# sg_uf                                  0.007736
# natureza_juridica_macro                0.090397
# de_ramo                                0.103017
# setor                                  0.038227
# idade_empresa_anos                     0.087694
# idade_emp_cat                         -0.013581
# fl_me                                 -0.017343
# fl_sa                                  0.132027
# fl_epp                                      NaN
# fl_mei                                      NaN
# fl_ltda                               -0.019205
# dt_situacao                           -0.031319
# fl_st_especial                         0.015478
# fl_email                               0.049914
# fl_telefone                            0.034452
# fl_rm                                  0.112036
# nm_divisao                             0.046105
# nm_segmento                            0.107719
# fl_spa                                 0.007215
# fl_antt                                0.009345
# fl_veiculo                            -0.039121
# fl_optante_simples                    -0.061669
# vl_total_veiculos_pesados_grupo        0.057576
# vl_total_veiculos_leves_grupo          0.200647
# fl_optante_simei                            NaN
# sg_uf_matriz                           0.007736
# de_saude_tributaria                   -0.029636
# de_saude_rescencia                          NaN
# nu_meses_rescencia                    -0.014611
# de_nivel_atividade                    -0.049342
# fl_simples_irregular                  -0.012252
# fl_passivel_iss                       -0.024621
# de_faixa_faturamento_estimado          0.062476
# de_faixa_faturamento_estimado_grupo    0.083267
# vl_faturamento_estimado_aux            0.418647
# vl_faturamento_estimado_grupo_aux      0.600320
# qt_ex_funcionarios                     0.195367
# qt_funcionarios_grupo                  0.496978
# percent_func_genero_masc              -0.063711
# percent_func_genero_fem                0.063711
# total                                  0.414767
# meses_ultima_contratacaco             -0.081039
# qt_admitidos_12meses                   0.103307
# qt_desligados_12meses                  0.074920
# qt_desligados                          0.195394
# qt_admitidos                           0.361933
# media_meses_servicos_all              -0.017042
# max_meses_servicos_all                -0.010607
# min_meses_servicos_all                -0.044077
# media_meses_servicos                  -0.021730
# max_meses_servicos                     0.006458
# min_meses_servicos                    -0.082119
# qt_funcionarios                        0.414844
# qt_funcionarios_12meses                0.411015
# qt_funcionarios_24meses                0.401339
# tx_rotatividade                        0.015187
# qt_filiais                             1.000000
#
# [59 rows x 59 columns]

# %%
cor_market_portfolio_2_T2 = portfolio_2_T2.drop(['fl_matriz','fl_epp','fl_mei', 'fl_optante_simei', 'de_saude_rescencia'], axis = 1)
correlation = cor_market_portfolio_2_T2.corr(method="pearson")
f, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(correlation, center=True, square=True, annot=True, cmap="gist_gray",fmt='.2f', 
                 annot_kws={'size': 5});

# %% [markdown]
# >> ### Overview about Company 2's clients:

# %% [markdown]
# - Customers provide at least 60 data (already counting with the id);
# - They have 10 years or more of market, most of them have more than 20;
# - Most are from the service sector, but there are also commerce, industry, construction and agro;
# - Have revenues over 10 million reais;
# - Varied legal nature, but most are companies followed by municipalities and public agencies;
# - Various fields of activity but the main one is public administration, defense and social security;
# - The data: fl_matriz always has value "True";
# - The data: fl_me, fl_mei, fl_epp and fl_optante_simei always have a value of “False”.

# %% [markdown]
# > ## Exploring the Portfolio 3 Dataset:

# %% [markdown]
# >> ### Data types:

# %%
# The dataset portifolio_2 has only the column 'id', we will complete with the other data that are present in the dataset market.
portfolio_3_T1 = pd.DataFrame(portfolio_3['id'])
portfolio_3_T1 = pd.merge(portfolio_3_T1, market, on='id', how='left')

tipos_de_dados_portfolio_3_T1 = portfolio_3_T1.dtypes
tipos_de_dados_portfolio_3_T1
# Out:
# id                                                object
# Unnamed: 0                                         int64
# fl_matriz                                           bool
# de_natureza_juridica                              object
# sg_uf                                             object
# natureza_juridica_macro                           object
# de_ramo                                           object
# setor                                             object
# idade_empresa_anos                               float64
# idade_emp_cat                                     object
# fl_me                                               bool
# fl_sa                                               bool
# fl_epp                                              bool
# fl_mei                                              bool
# fl_ltda                                             bool
# dt_situacao                                       object
# fl_st_especial                                      bool
# fl_email                                            bool
# fl_telefone                                         bool
# fl_rm                                             object
# nm_divisao                                        object
# nm_segmento                                       object
# fl_spa                                            object
# fl_antt                                           object
# fl_veiculo                                        object
# vl_total_tancagem                                float64
# vl_total_veiculos_antt                           float64
# vl_total_veiculos_leves                          float64
# vl_total_veiculos_pesados                        float64
# fl_optante_simples                                object
#                                                   ...
# idade_de_34_a_38                                 float64
# idade_de_39_a_43                                 float64
# idade_de_44_a_48                                 float64
# idade_de_49_a_53                                 float64
# idade_de_54_a_58                                 float64
# idade_acima_de_58                                float64
# grau_instrucao_macro_analfabeto                  float64
# grau_instrucao_macro_escolaridade_fundamental    float64
# grau_instrucao_macro_escolaridade_media          float64
# grau_instrucao_macro_escolaridade_superior       float64
# grau_instrucao_macro_desconhecido                float64
# total                                            float64
# meses_ultima_contratacaco                        float64
# qt_admitidos_12meses                             float64
# qt_desligados_12meses                            float64
# qt_desligados                                    float64
# qt_admitidos                                     float64
# media_meses_servicos_all                         float64
# max_meses_servicos_all                           float64
# min_meses_servicos_all                           float64
# media_meses_servicos                             float64
# max_meses_servicos                               float64
# min_meses_servicos                               float64
# qt_funcionarios                                  float64
# qt_funcionarios_12meses                          float64
# qt_funcionarios_24meses                          float64
# tx_crescimento_12meses                           float64
# tx_crescimento_24meses                           float64
# tx_rotatividade                                  float64
# qt_filiais                                         int64
# Length: 182, dtype: object

# %% [markdown]
# >> ### Number of columns with NA's:

# %%
qt_cols_na_portfolio_3_T1 = len(portfolio_3_T1.columns[portfolio_3_T1.isna().any()])
qt_cols_na_portfolio_3_T1
# Out:
# 118

# %% [markdown]
# >> ### Number of columns without NA's:

# %%
qt_cols_wtt_na_portfolio_3_T1 = len(portfolio_3_T1.columns) - qt_cols_na_portfolio_3_T1
qt_cols_wtt_na_portfolio_3_T1
# Out:
# 64

# %% [markdown]
# >> ### NA's count per column:

# %%
qt_na_per_col_portfolio_3_T1 = portfolio_3_T1.isna().sum().sort_values(ascending=False)
qt_na_per_col_portfolio_3_T1
# Out:
# qt_alteracao_socio_365d                265
# vl_total_veiculos_antt_grupo           265
# grau_instrucao_macro_desconhecido      265
# qt_socios_st_suspensa                  265
# vl_total_veiculos_antt                 265
# qt_alteracao_socio_total               265
# qt_alteracao_socio_90d                 265
# qt_alteracao_socio_180d                265
# coligada_mais_nova_baixada             264
# idade_media_coligadas_baixadas         264
# coligada_mais_antiga_baixada           264
# vl_total_tancagem_grupo                255
# vl_total_tancagem                      255
# qt_socios_pep                          253
# qt_socios_pj_nulos                     250
# qt_socios_pj_baixados                  250
# qt_socios_pj_suspensos                 250
# qt_socios_pj_inaptos                   250
# vl_idade_media_socios_pj               250
# vl_idade_maxima_socios_pj              250
# vl_idade_minima_socios_pj              250
# qt_socios_pj_ativos                    250
# vl_potenc_cons_oleo_gas                243
# max_filiais_coligados                  229
# media_filiais_coligados                229
# min_filiais_coligados                  229
# total_filiais_coligados                229
# qt_socios_feminino                     222
# idade_ate_18                           208
# vl_folha_coligados                     207
#                                       ...
# media_meses_servicos_all                 0
# max_meses_servicos_all                   0
# min_meses_servicos_all                   0
# media_meses_servicos                     0
# max_meses_servicos                       0
# min_meses_servicos                       0
# qt_funcionarios                          0
# qt_funcionarios_12meses                  0
# qt_funcionarios_24meses                  0
# tx_crescimento_12meses                   0
# total                                    0
# idade_de_49_a_53                         0
# de_saude_tributaria                      0
# idade_de_44_a_48                         0
# de_saude_rescencia                       0
# de_nivel_atividade                       0
# fl_simples_irregular                     0
# fl_passivel_iss                          0
# tx_rotatividade                          0
# de_faixa_faturamento_estimado            0
# de_faixa_faturamento_estimado_grupo      0
# vl_faturamento_estimado_aux              0
# vl_faturamento_estimado_grupo_aux        0
# qt_ex_funcionarios                       0
# qt_funcionarios_grupo                    0
# percent_func_genero_masc                 0
# percent_func_genero_fem                  0
# idade_de_34_a_38                         0
# idade_de_39_a_43                         0
# id                                       0
# Length: 182, dtype: int64

# %% [markdown]
# >> ### Dataframe portfolio 2 without columns with NA's:

# %%
portfolio_3_T2 = portfolio_3_T1.dropna(axis = 'columns')
portfolio_3_T2 = portfolio_3_T2.drop(['Unnamed: 0'], axis = 1) # Delete column'Unnamed: 0'.
portfolio_3_T2.head()
# Out:
#                                                   id  fl_matriz  \
# 0  bb61c09449a1c1f8b78955d8b7a7f73599e78358993fe2...       True
# 1  16843c9ffb920170477118933798510d8d5f00f5c56c12...       True
# 2  1b8d092daff12bed8b3c2ab93bf5df2921865a68aca185...       True
# 3  3aafa3a1f12f483740a52956af100223333d0e3c79bf2c...       True
# 4  c60431fbca90067f105570e1e8a684bcd7048205bbf6c4...       True
#
#                                 de_natureza_juridica sg_uf  \
# 0                                          MUNICIPIO    MA
# 1                         SOCIEDADE SIMPLES LIMITADA    PI
# 2  ORGAO PUBLICO DO PODER EXECUTIVO ESTADUAL OU D...    AM
# 3                                          MUNICIPIO    PI
# 4                                          MUNICIPIO    RN
#
#   natureza_juridica_macro                                            de_ramo  \
# 0                  OUTROS  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
# 1  ENTIDADES EMPRESARIAIS                               SERVICOS DE EDUCACAO
# 2   ADMINISTRACAO PUBLICA  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
# 3                  OUTROS  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
# 4                  OUTROS  ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE SOCIAL
#
#      setor  idade_empresa_anos idade_emp_cat  fl_me  ...  \
# 0  SERVIÇO           21.813699          > 20  False  ...
# 1  SERVIÇO           16.389041       15 a 20  False  ...
# 2  SERVIÇO           40.380822          > 20  False  ...
# 3  SERVIÇO           43.854795          > 20  False  ...
# 4  SERVIÇO           43.865753          > 20  False  ...
#
#    min_meses_servicos_all  media_meses_servicos  max_meses_servicos  \
# 0               -2.466667            144.663535          259.166667
# 1                0.000000             65.942017          149.033333
# 2                0.633333            284.854706          557.866667
# 3                8.733333            189.020309          506.966667
# 4               -0.066667            238.418341          556.833333
#
#    min_meses_servicos qt_funcionarios  qt_funcionarios_12meses  \
# 0           40.500000           745.0                    745.0
# 1            4.866667           119.0                    104.0
# 2           24.200000           170.0                    170.0
# 3           31.333333           151.0                    151.0
# 4           34.033333           229.0                    229.0
#
#    qt_funcionarios_24meses  tx_crescimento_12meses tx_rotatividade qt_filiais
# 0                    745.0                0.000000            0.00          2
# 1                    113.0               14.423077            6.25          0
# 2                    177.0                0.000000            0.00          0
# 3                    151.0                0.000000            0.00          0
# 4                    418.0                0.000000            0.00          1
#
# [5 rows x 63 columns]

# %%
print("After this first handling, the portfolio 3 dimensions (row, column) are:", portfolio_3_T2.shape)
# Out:
# After this first handling, the portfolio 3 dimensions (row, column) are: (265, 63)

# %% [markdown]
# >> ### Unique Values:

# %%
# First an adjustment in the 'idade_empresa_anos' column that floats:
portfolio_3_T2['idade_empresa_anos'] = portfolio_3_T2['idade_empresa_anos'].round().astype(int)
portfolio_3_T2['vl_total_veiculos_pesados_grupo'] = portfolio_3_T2['vl_total_veiculos_pesados_grupo'].round().astype(int)
portfolio_3_T2['vl_total_veiculos_leves_grupo'] = portfolio_3_T2['vl_total_veiculos_leves_grupo'].round().astype(int)
portfolio_3_T2['vl_faturamento_estimado_aux'] = portfolio_3_T2['vl_faturamento_estimado_aux'].round().astype(int)
portfolio_3_T2['vl_faturamento_estimado_grupo_aux'] = portfolio_3_T2['vl_faturamento_estimado_grupo_aux'].round().astype(int)
portfolio_3_T2['qt_ex_funcionarios'] = portfolio_3_T2['qt_ex_funcionarios'].round().astype(int)
portfolio_3_T2['qt_funcionarios_grupo'] = portfolio_3_T2['qt_funcionarios_grupo'].round().astype(int)
portfolio_3_T2['percent_func_genero_masc'] = portfolio_3_T2['percent_func_genero_masc'].round().astype(int)
portfolio_3_T2['percent_func_genero_fem'] = portfolio_3_T2['percent_func_genero_fem'].round().astype(int)
portfolio_3_T2['idade_de_34_a_38'] = portfolio_3_T2['idade_de_34_a_38'].round().astype(int)
portfolio_3_T2['idade_de_39_a_43'] = portfolio_3_T2['idade_de_39_a_43'].round().astype(int)
portfolio_3_T2['idade_de_44_a_48'] = portfolio_3_T2['idade_de_44_a_48'].round().astype(int)
portfolio_3_T2['idade_de_49_a_53'] = portfolio_3_T2['idade_de_49_a_53'].round().astype(int)
portfolio_3_T2['grau_instrucao_macro_escolaridade_media'] = portfolio_3_T2['grau_instrucao_macro_escolaridade_media'].round().astype(int)
portfolio_3_T2['total'] = portfolio_3_T2['total'].round().astype(int)
portfolio_3_T2['meses_ultima_contratacaco'] = portfolio_3_T2['meses_ultima_contratacaco'].round().astype(int)
portfolio_3_T2['qt_admitidos_12meses'] = portfolio_3_T2['qt_admitidos_12meses'].round().astype(int)
portfolio_3_T2['qt_desligados_12meses'] = portfolio_3_T2['qt_desligados_12meses'].round().astype(int)
portfolio_3_T2['qt_desligados'] = portfolio_3_T2['qt_desligados'].round().astype(int)
portfolio_3_T2['qt_admitidos'] = portfolio_3_T2['qt_admitidos'].round().astype(int)
portfolio_3_T2['media_meses_servicos_all'] = portfolio_3_T2['media_meses_servicos_all'].round().astype(int)
portfolio_3_T2['max_meses_servicos_all'] = portfolio_3_T2['max_meses_servicos_all'].round().astype(int)
portfolio_3_T2['min_meses_servicos_all'] = portfolio_3_T2['min_meses_servicos_all'].round().astype(int)
portfolio_3_T2['media_meses_servicos'] = portfolio_3_T2['media_meses_servicos'].round().astype(int)
portfolio_3_T2['max_meses_servicos'] = portfolio_3_T2['max_meses_servicos'].round().astype(int)
portfolio_3_T2['min_meses_servicos'] = portfolio_3_T2['min_meses_servicos'].round().astype(int)
portfolio_3_T2['qt_funcionarios'] = portfolio_3_T2['qt_funcionarios'].round().astype(int)
portfolio_3_T2['qt_funcionarios_12meses'] = portfolio_3_T2['qt_funcionarios_12meses'].round().astype(int)
portfolio_3_T2['qt_funcionarios_24meses'] = portfolio_3_T2['qt_funcionarios_24meses'].round().astype(int)
portfolio_3_T2['tx_crescimento_12meses'] = portfolio_3_T2['tx_crescimento_12meses'].round().astype(int)
portfolio_3_T2['tx_rotatividade'] = portfolio_3_T2['tx_rotatividade'].round().astype(int)

# %%
qt_val_uni_portfolio_3_T2 = portfolio_3_T2.nunique()
data_types_portfolio_3_T2 = portfolio_3_T2.dtypes
portfolio_3_T2_qt_un_tp = pd.concat([qt_val_uni_portfolio_3_T2, data_types_portfolio_3_T2], axis = 1).reset_index()
portfolio_3_T2_qt_un_tp.columns = ['Column', 'Unique_values', 'Tipo']
portfolio_3_T2_qt_un_tp
# Out:
#                                      Column  Unique_values    Tipo
# 0                                        id            265  object
# 1                                 fl_matriz              1    bool
# 2                      de_natureza_juridica             25  object
# 3                                     sg_uf              6  object
# 4                   natureza_juridica_macro              4  object
# 5                                   de_ramo             16  object
# 6                                     setor              1  object
# 7                        idade_empresa_anos             52   int64
# 8                             idade_emp_cat              6  object
# 9                                     fl_me              1    bool
# 10                                    fl_sa              2    bool
# 11                                   fl_epp              1    bool
# 12                                   fl_mei              1    bool
# 13                                  fl_ltda              2    bool
# 14                              dt_situacao            129  object
# 15                           fl_st_especial              1    bool
# 16                                 fl_email              2    bool
# 17                              fl_telefone              2    bool
# 18                                    fl_rm              2  object
# 19                               nm_divisao             26  object
# 20                              nm_segmento             13  object
# 21                                   fl_spa              2  object
# 22                                  fl_antt              2  object
# 23                               fl_veiculo              2  object
# 24          vl_total_veiculos_pesados_grupo             32   int64
# 25            vl_total_veiculos_leves_grupo             41   int64
# 26                             sg_uf_matriz              6  object
# 27                      de_saude_tributaria              5  object
# 28                       de_saude_rescencia              3  object
# 29                       de_nivel_atividade              3  object
# ..                                      ...            ...     ...
# 33      de_faixa_faturamento_estimado_grupo              6  object
# 34              vl_faturamento_estimado_aux            248   int64
# 35        vl_faturamento_estimado_grupo_aux            256   int64
# 36                       qt_ex_funcionarios            222   int64
# 37                    qt_funcionarios_grupo            233   int64
# 38                 percent_func_genero_masc             73   int64
# 39                  percent_func_genero_fem             73   int64
# 40                         idade_de_34_a_38            123   int64
# 41                         idade_de_39_a_43            129   int64
# 42                         idade_de_44_a_48            119   int64
# 43                         idade_de_49_a_53            116   int64
# 44  grau_instrucao_macro_escolaridade_media            196   int64
# 45                                    total            225   int64
# 46                meses_ultima_contratacaco             43   int64
# 47                     qt_admitidos_12meses             73   int64
# 48                    qt_desligados_12meses             73   int64
# 49                            qt_desligados            216   int64
# 50                             qt_admitidos            241   int64
# 51                 media_meses_servicos_all            168   int64
# 52                   max_meses_servicos_all            126   int64
# 53                   min_meses_servicos_all             32   int64
# 54                     media_meses_servicos            166   int64
# 55                       max_meses_servicos            183   int64
# 56                       min_meses_servicos             44   int64
# 57                          qt_funcionarios            231   int64
# 58                  qt_funcionarios_12meses            230   int64
# 59                  qt_funcionarios_24meses            234   int64
# 60                   tx_crescimento_12meses             44   int64
# 61                          tx_rotatividade             39   int64
# 62                               qt_filiais             21   int64
#
# [63 rows x 3 columns]

# %% [markdown]
# >> ### Frequency of Unique Values:

# %%
freq_val_uni_portfolio_3_T2 = portfolio_3_T2.drop(['id'], axis =1).apply(lambda x: [x.value_counts().to_dict()])
freq_val_uni_portfolio_3_T2
# Out:
# fl_matriz                                                                      [{True: 265}]
# de_natureza_juridica                       [{'MUNICIPIO': 108, 'SOCIEDADE EMPRESARIA LIMI...
# sg_uf                                      [{'MA': 74, 'PI': 52, 'RN': 51, 'AM': 43, 'AC'...
# natureza_juridica_macro                    [{'OUTROS': 128, 'ENTIDADES EMPRESARIAIS': 73,...
# de_ramo                                    [{'ADMINISTRACAO PUBLICA, DEFESA E SEGURIDADE ...
# setor                                                                     [{'SERVIÇO': 265}]
# idade_empresa_anos                         [{44: 50, 22: 30, 20: 10, 19: 9, 10: 9, 26: 9,...
# idade_emp_cat                              [{'> 20': 176, '15 a 20': 33, '5 a 10': 27, '1...
# fl_me                                                                         [{False: 265}]
# fl_sa                                                                [{False: 260, True: 5}]
# fl_epp                                                                        [{False: 265}]
# fl_mei                                                                        [{False: 265}]
# fl_ltda                                                              [{False: 264, True: 1}]
# dt_situacao                                [{'2005-11-03': 85, '1998-07-28': 13, '2005-09...
# fl_st_especial                                                                [{False: 265}]
# fl_email                                                           [{False: 147, True: 118}]
# fl_telefone                                                        [{False: 133, True: 132}]
# fl_rm                                                             [{'NAO': 145, 'SIM': 120}]
# nm_divisao                                 [{'ADMINISTRACAO PUBLICA DEFESA E SEGURIDADE S...
# nm_segmento                                [{'ADMINISTRACAO PUBLICA DEFESA E SEGURIDADE S...
# fl_spa                                                              [{False: 255, True: 10}]
# fl_antt                                                             [{False: 253, True: 12}]
# fl_veiculo                                                          [{True: 221, False: 44}]
# vl_total_veiculos_pesados_grupo            [{0: 105, 1: 34, 4: 17, 8: 12, 6: 12, 3: 11, 2...
# vl_total_veiculos_leves_grupo              [{0: 66, 1: 31, 2: 22, 3: 20, 4: 17, 6: 14, 7:...
# sg_uf_matriz                               [{'MA': 74, 'PI': 52, 'RN': 51, 'AM': 43, 'AC'...
# de_saude_tributaria                        [{'VERDE': 159, 'AZUL': 83, 'LARANJA': 20, 'VE...
# de_saude_rescencia                         [{'ACIMA DE 1 ANO': 263, 'ATE 1 ANO': 1, 'SEM ...
# de_nivel_atividade                                  [{'ALTA': 236, 'MEDIA': 26, 'BAIXA': 3}]
# fl_simples_irregular                                                 [{False: 264, True: 1}]
#                                                                  ...
# de_faixa_faturamento_estimado_grupo        [{'DE R$ 30.000.000,01 A R$ 100.000.000,00': 1...
# vl_faturamento_estimado_aux                [{24624648: 3, 27870156: 2, 20606400: 2, 11740...
# vl_faturamento_estimado_grupo_aux          [{23388264: 2, 68310216: 2, 27870156: 2, 24882...
# qt_ex_funcionarios                         [{60: 3, 15: 3, 36: 3, 84: 3, 221: 3, 172: 3, ...
# qt_funcionarios_grupo                      [{353: 3, 317: 3, 190: 3, 148: 2, 119: 2, 292:...
# percent_func_genero_masc                   [{32: 14, 31: 12, 38: 9, 48: 8, 33: 8, 40: 7, ...
# percent_func_genero_fem                    [{68: 14, 69: 12, 62: 9, 67: 8, 52: 8, 64: 7, ...
# idade_de_34_a_38                           [{28: 8, 21: 7, 34: 6, 42: 6, 33: 6, 27: 6, 41...
# idade_de_39_a_43                           [{41: 12, 31: 7, 46: 6, 24: 6, 33: 5, 14: 5, 3...
# idade_de_44_a_48                           [{20: 9, 18: 7, 11: 7, 9: 7, 12: 5, 32: 5, 33:...
# idade_de_49_a_53                           [{14: 9, 28: 6, 7: 6, 30: 6, 15: 6, 31: 6, 22:...
# grau_instrucao_macro_escolaridade_media    [{134: 4, 49: 4, 145: 4, 219: 3, 117: 3, 107: ...
# total                                      [{353: 3, 317: 3, 190: 3, 151: 3, 183: 3, 722:...
# meses_ultima_contratacaco                  [{2: 48, 3: 36, 23: 28, 25: 23, 24: 21, 28: 11...
# qt_admitidos_12meses                       [{0: 162, 12: 3, 87: 3, 35: 3, 13: 3, 18: 3, 1...
# qt_desligados_12meses                      [{0: 159, 27: 6, 9: 5, 8: 4, 22: 4, 1: 3, 29: ...
# qt_desligados                              [{164: 4, 172: 3, 221: 3, 84: 3, 36: 3, 60: 3,...
# qt_admitidos                               [{1633: 2, 410: 2, 465: 2, 446: 2, 1212: 2, 22...
# media_meses_servicos_all                   [{18: 6, 21: 5, 24: 4, 92: 4, 20: 4, 27: 4, 14...
# max_meses_servicos_all                     [{5015: 91, 266: 8, 5099: 6, 5065: 5, 154: 4, ...
# min_meses_servicos_all                     [{0: 82, -1: 51, 1: 29, 2: 16, 3: 14, 8: 6, -4...
# media_meses_servicos                       [{45: 5, 182: 5, 170: 4, 169: 4, 155: 4, 30: 4...
# max_meses_servicos                         [{266: 9, 507: 8, 5099: 6, 471: 5, 521: 5, 264...
# min_meses_servicos                         [{2: 48, 3: 36, 23: 24, 25: 20, 24: 18, 28: 12...
# qt_funcionarios                            [{192: 2, 433: 2, 199: 2, 353: 2, 378: 2, 191:...
# qt_funcionarios_12meses                    [{191: 4, 141: 3, 327: 3, 223: 2, 85: 2, 94: 2...
# qt_funcionarios_24meses                    [{327: 4, 205: 3, 348: 3, 153: 3, 145: 3, 177:...
# tx_crescimento_12meses                     [{0: 168, 6: 9, -3: 8, 2: 7, 3: 7, -1: 6, 5: 6...
# tx_rotatividade                            [{0: 162, 3: 7, 20: 7, 23: 6, 16: 6, 13: 6, 4:...
# qt_filiais                                 [{0: 155, 1: 53, 2: 17, 3: 10, 5: 4, 7: 3, 4: ...
# Length: 62, dtype: object

# %% [markdown]
# >> ### Data Visualization:

# %% [markdown]
# >> ### Graphs:

# %%
f, axes= plt.subplots(7, 3, figsize=(18, 35))

sns.countplot(data=portfolio_3_T2, x="fl_matriz", palette = 'gist_gray', order = portfolio_3_T2['fl_matriz'].value_counts().index, ax=axes[0,0]);
axes[0,0].set_title("fl_matriz")
axes[0,0].set_ylabel("")
axes[0,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="sg_uf", palette = 'gist_gray', order = portfolio_3_T2['sg_uf'].value_counts().index, ax=axes[0,1]);
axes[0,1].set_title("sg_uf")
axes[0,1].set_ylabel("")
axes[0,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="idade_emp_cat", palette = 'gist_gray', order = portfolio_3_T2['idade_emp_cat'].value_counts().index, ax=axes[0,2]);
axes[0,2].set_title("idade_emp_cat")
axes[0,2].set_ylabel("")
axes[0,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_me", palette = 'gist_gray', order = portfolio_3_T2['fl_me'].value_counts().index, ax=axes[1,0]);
axes[1,0].set_title("fl_me")
axes[1,0].set_ylabel("")
axes[1,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_sa", palette = 'gist_gray', order = portfolio_3_T2['fl_sa'].value_counts().index, ax=axes[1,1]);
axes[1,1].set_title("fl_sa")
axes[1,1].set_ylabel("")
axes[1,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_mei", palette = 'gist_gray', order = portfolio_3_T2['fl_mei'].value_counts().index, ax=axes[1,2]);
axes[1,2].set_title("fl_mei")
axes[1,2].set_ylabel("")
axes[1,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_ltda", palette = 'gist_gray', order = portfolio_3_T2['fl_ltda'].value_counts().index, ax=axes[2,0]);
axes[2,0].set_title("fl_ltda")
axes[2,0].set_ylabel("")
axes[2,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_st_especial", palette = 'gist_gray', order = portfolio_3_T2['fl_st_especial'].value_counts().index, ax=axes[2,1]);
axes[2,1].set_title("fl_st_especial")
axes[2,1].set_ylabel("")
axes[2,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_email", palette = 'gist_gray', order = portfolio_3_T2['fl_email'].value_counts().index, ax=axes[2,2]);
axes[2,2].set_title("fl_email")
axes[2,2].set_ylabel("")
axes[2,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_telefone", palette = 'gist_gray', order = portfolio_3_T2['fl_telefone'].value_counts().index, ax=axes[3,0]);
axes[3,0].set_title("fl_telefone")
axes[3,0].set_ylabel("")
axes[3,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_rm", palette = 'gist_gray', order = portfolio_3_T2['fl_rm'].value_counts().index, ax=axes[3,1]);
axes[3,1].set_title("fl_rm")
axes[3,1].set_ylabel("")
axes[3,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_epp", palette = 'gist_gray', order = portfolio_3_T2['fl_epp'].value_counts().index, ax=axes[3,2]);
axes[3,2].set_title("fl_epp")
axes[3,2].set_ylabel("")
axes[3,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="setor", palette = 'gist_gray', order = portfolio_3_T2['setor'].value_counts().index, ax=axes[4,0]);
axes[4,0].set_title("setor")
axes[4,0].set_ylabel("")
axes[4,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="sg_uf_matriz", palette = 'gist_gray', order = portfolio_3_T2['sg_uf_matriz'].value_counts().index, ax=axes[4,1]);
axes[4,1].set_title("sg_uf_matriz")
axes[4,1].set_ylabel("")
axes[4,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_passivel_iss", palette = 'gist_gray', order = portfolio_3_T2['fl_passivel_iss'].value_counts().index, ax=axes[4,2]);
axes[4,2].set_title("fl_passivel_iss")
axes[4,2].set_ylabel("")
axes[4,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_spa", palette = 'gist_gray', order = portfolio_3_T2['fl_spa'].value_counts().index, ax=axes[5,0]);
axes[5,0].set_title("fl_spa")
axes[5,0].set_ylabel("")
axes[5,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_antt", palette = 'gist_gray', order = portfolio_3_T2['fl_antt'].value_counts().index, ax=axes[5,1]);
axes[5,1].set_title("fl_antt")
axes[5,1].set_ylabel("")
axes[5,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_veiculo", palette = 'gist_gray', order = portfolio_3_T2['fl_veiculo'].value_counts().index, ax=axes[5,2]);
axes[5,2].set_title("fl_veiculo")
axes[5,2].set_ylabel("")
axes[5,2].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="de_nivel_atividade", palette = 'gist_gray', order = portfolio_3_T2['de_nivel_atividade'].value_counts().index, ax=axes[6,0]);
axes[6,0].set_title("de_nivel_atividade")
axes[6,0].set_ylabel("")
axes[6,0].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="fl_simples_irregular", palette = 'gist_gray', order = portfolio_3_T2['fl_simples_irregular'].value_counts().index, ax=axes[6,1]);
axes[6,1].set_title("fl_simples_irregular")
axes[6,1].set_ylabel("")
axes[6,1].set_xlabel("")

sns.countplot(data=portfolio_3_T2, x="de_saude_tributaria", palette = 'gist_gray', order = portfolio_3_T2['de_saude_tributaria'].value_counts().index, ax=axes[6,2]);
axes[6,2].set_title("de_saude_tributaria")
axes[6,2].set_ylabel("")
axes[6,2].set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="qt_filiais", palette = 'gist_gray', order = portfolio_3_T2['qt_filiais'].value_counts().index);
ax.set_title("qt_filiais")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="de_faixa_faturamento_estimado", palette = 'gist_gray', order = portfolio_3_T2['de_faixa_faturamento_estimado'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_faixa_faturamento_estimado")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="natureza_juridica_macro", palette = 'gist_gray', order = portfolio_3_T2['natureza_juridica_macro'].value_counts().index);
ax.set_title("natureza_juridica_macro")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="nm_divisao", palette = 'gist_gray', order = portfolio_3_T2['nm_divisao'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_divisao")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="nm_segmento", palette = 'gist_gray', order = portfolio_3_T2['nm_segmento'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("nm_segmento")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="de_natureza_juridica", palette = 'gist_gray', order = portfolio_3_T2['de_natureza_juridica'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_natureza_juridica")
ax.set_ylabel("")
ax.set_xlabel("")


fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="de_ramo", palette = 'gist_gray', order = portfolio_3_T2['de_ramo'].value_counts().index);
plt.xticks(rotation=90)
ax.set_title("de_ramo")
ax.set_ylabel("")
ax.set_xlabel("")

fig, ax = plt.subplots(figsize=(18,5))
sns.countplot(data=portfolio_3_T2, x="idade_empresa_anos", palette = 'gist_gray', order = portfolio_3_T2['idade_empresa_anos'].value_counts().index);
ax.set_title("idade_empresa_anos")
ax.set_ylabel("")
ax.set_xlabel("")

plt.show()

# %% [markdown]
# >> ### Correlations:

# %%
# Convert object columns to numeric value
portfolio_3_T2['de_natureza_juridica'] = pd.factorize(portfolio_3_T2['de_natureza_juridica'])[0]
portfolio_3_T2['sg_uf'] = pd.factorize(portfolio_3_T2['sg_uf'])[0]
portfolio_3_T2['natureza_juridica_macro'] = pd.factorize(portfolio_3_T2['natureza_juridica_macro'])[0]
portfolio_3_T2['de_ramo'] = pd.factorize(portfolio_3_T2['de_ramo'])[0]
portfolio_3_T2['setor'] = pd.factorize(portfolio_3_T2['setor'])[0]
portfolio_3_T2['idade_emp_cat'] = pd.factorize(portfolio_3_T2['idade_emp_cat'])[0]
portfolio_3_T2['dt_situacao'] = pd.factorize(portfolio_3_T2['dt_situacao'])[0]
portfolio_3_T2['fl_rm'] = pd.factorize(portfolio_3_T2['fl_rm'])[0]
portfolio_3_T2['nm_divisao'] = pd.factorize(portfolio_3_T2['nm_divisao'])[0]
portfolio_3_T2['nm_segmento'] = pd.factorize(portfolio_3_T2['nm_segmento'])[0]
portfolio_3_T2['sg_uf_matriz'] = pd.factorize(portfolio_3_T2['sg_uf_matriz'])[0]
portfolio_3_T2['fl_spa'] = pd.factorize(portfolio_3_T2['fl_spa'])[0]
portfolio_3_T2['fl_antt'] = pd.factorize(portfolio_3_T2['fl_antt'])[0]
portfolio_3_T2['fl_veiculo'] = pd.factorize(portfolio_3_T2['fl_veiculo'])[0]
portfolio_3_T2['de_saude_tributaria'] = pd.factorize(portfolio_3_T2['de_saude_tributaria'])[0]
portfolio_3_T2['de_saude_rescencia'] = pd.factorize(portfolio_3_T2['de_saude_rescencia'])[0]
portfolio_3_T2['de_nivel_atividade'] = pd.factorize(portfolio_3_T2['de_nivel_atividade'])[0]
portfolio_3_T2['fl_simples_irregular'] = pd.factorize(portfolio_3_T2['fl_simples_irregular'])[0]
portfolio_3_T2['fl_passivel_iss'] = pd.factorize(portfolio_3_T2['fl_passivel_iss'])[0]
portfolio_3_T2['de_faixa_faturamento_estimado'] = pd.factorize(portfolio_3_T2['de_faixa_faturamento_estimado'])[0]
portfolio_3_T2['de_faixa_faturamento_estimado_grupo'] = pd.factorize(portfolio_3_T2['de_faixa_faturamento_estimado_grupo'])[0]

# %%
correlation = portfolio_3_T2.corr(method="pearson")
correlation
# Out:
#                                          fl_matriz  idade_empresa_anos  fl_me  \
# fl_matriz                                      NaN                 NaN    NaN
# idade_empresa_anos                             NaN            1.000000    NaN
# fl_me                                          NaN                 NaN    NaN
# fl_sa                                          NaN            0.078355    NaN
# fl_epp                                         NaN                 NaN    NaN
# fl_mei                                         NaN                 NaN    NaN
# fl_ltda                                        NaN            0.070537    NaN
# fl_st_especial                                 NaN                 NaN    NaN
# fl_email                                       NaN           -0.456535    NaN
# fl_telefone                                    NaN           -0.495281    NaN
# vl_total_veiculos_pesados_grupo                NaN            0.060143    NaN
# vl_total_veiculos_leves_grupo                  NaN           -0.028472    NaN
# vl_faturamento_estimado_aux                    NaN            0.011230    NaN
# vl_faturamento_estimado_grupo_aux              NaN            0.022590    NaN
# qt_ex_funcionarios                             NaN           -0.044571    NaN
# qt_funcionarios_grupo                          NaN            0.138152    NaN
# percent_func_genero_masc                       NaN           -0.316048    NaN
# percent_func_genero_fem                        NaN            0.316048    NaN
# idade_de_34_a_38                               NaN            0.104796    NaN
# idade_de_39_a_43                               NaN            0.239854    NaN
# idade_de_44_a_48                               NaN            0.291110    NaN
# idade_de_49_a_53                               NaN            0.288276    NaN
# grau_instrucao_macro_escolaridade_media        NaN            0.096178    NaN
# total                                          NaN            0.145751    NaN
# meses_ultima_contratacaco                      NaN            0.335423    NaN
# qt_admitidos_12meses                           NaN           -0.317845    NaN
# qt_desligados_12meses                          NaN           -0.249789    NaN
# qt_desligados                                  NaN           -0.044636    NaN
# qt_admitidos                                   NaN            0.032332    NaN
# media_meses_servicos_all                       NaN            0.419611    NaN
# max_meses_servicos_all                         NaN            0.396911    NaN
# min_meses_servicos_all                         NaN            0.030244    NaN
# media_meses_servicos                           NaN            0.536651    NaN
# max_meses_servicos                             NaN            0.090446    NaN
# min_meses_servicos                             NaN            0.319070    NaN
# qt_funcionarios                                NaN            0.145029    NaN
# qt_funcionarios_12meses                        NaN            0.156250    NaN
# qt_funcionarios_24meses                        NaN            0.176955    NaN
# tx_crescimento_12meses                         NaN           -0.123002    NaN
# tx_rotatividade                                NaN           -0.424699    NaN
# qt_filiais                                     NaN            0.064457    NaN
#
#                                             fl_sa  fl_epp  fl_mei   fl_ltda  \
# fl_matriz                                     NaN     NaN     NaN       NaN
# idade_empresa_anos                       0.078355     NaN     NaN  0.070537
# fl_me                                         NaN     NaN     NaN       NaN
# fl_sa                                    1.000000     NaN     NaN -0.008535
# fl_epp                                        NaN     NaN     NaN       NaN
# fl_mei                                        NaN     NaN     NaN       NaN
# fl_ltda                                 -0.008535     NaN     NaN  1.000000
# fl_st_especial                                NaN     NaN     NaN       NaN
# fl_email                                -0.012635     NaN     NaN -0.055142
# fl_telefone                              0.028259     NaN     NaN  0.061778
# vl_total_veiculos_pesados_grupo         -0.010435     NaN     NaN -0.020199
# vl_total_veiculos_leves_grupo            0.026666     NaN     NaN -0.018105
# vl_faturamento_estimado_aux              0.141562     NaN     NaN -0.019090
# vl_faturamento_estimado_grupo_aux        0.145455     NaN     NaN -0.020108
# qt_ex_funcionarios                       0.027975     NaN     NaN -0.005955
# qt_funcionarios_grupo                    0.173820     NaN     NaN -0.031981
# percent_func_genero_masc                 0.097347     NaN     NaN  0.006365
# percent_func_genero_fem                 -0.097347     NaN     NaN -0.006365
# idade_de_34_a_38                         0.153762     NaN     NaN -0.043371
# idade_de_39_a_43                         0.039817     NaN     NaN -0.037177
# idade_de_44_a_48                        -0.006848     NaN     NaN -0.026471
# idade_de_49_a_53                        -0.035171     NaN     NaN -0.035093
# grau_instrucao_macro_escolaridade_media  0.180218     NaN     NaN -0.044695
# total                                    0.153191     NaN     NaN -0.030790
# meses_ultima_contratacaco               -0.025098     NaN     NaN -0.062640
# qt_admitidos_12meses                     0.127325     NaN     NaN -0.013562
# qt_desligados_12meses                    0.131865     NaN     NaN -0.008150
# qt_desligados                            0.028056     NaN     NaN -0.005991
# qt_admitidos                             0.090692     NaN     NaN -0.018397
# media_meses_servicos_all                -0.023430     NaN     NaN -0.024067
# max_meses_servicos_all                  -0.045727     NaN     NaN -0.047154
# min_meses_servicos_all                  -0.025801     NaN     NaN -0.011451
# media_meses_servicos                     0.018896     NaN     NaN  0.012248
# max_meses_servicos                      -0.002315     NaN     NaN -0.008892
# min_meses_servicos                      -0.023081     NaN     NaN -0.061009
# qt_funcionarios                          0.154004     NaN     NaN -0.030746
# qt_funcionarios_12meses                  0.153452     NaN     NaN -0.029594
# qt_funcionarios_24meses                  0.146374     NaN     NaN -0.029959
# tx_crescimento_12meses                  -0.009264     NaN     NaN -0.004254
# tx_rotatividade                         -0.032606     NaN     NaN  0.002202
# qt_filiais                               0.088444     NaN     NaN -0.013117
#
#                                          fl_st_especial  fl_email  \
# fl_matriz                                           NaN       NaN
# idade_empresa_anos                                  NaN -0.456535
# fl_me                                               NaN       NaN
# fl_sa                                               NaN -0.012635
# fl_epp                                              NaN       NaN
# fl_mei                                              NaN       NaN
# fl_ltda                                             NaN -0.055142
# fl_st_especial                                      NaN       NaN
# fl_email                                            NaN  1.000000
# fl_telefone                                         NaN  0.686735
# vl_total_veiculos_pesados_grupo                     NaN  0.014206
# vl_total_veiculos_leves_grupo                       NaN  0.110647
# vl_faturamento_estimado_aux                         NaN  0.115909
# vl_faturamento_estimado_grupo_aux                   NaN  0.113549
# qt_ex_funcionarios                                  NaN  0.008464
# qt_funcionarios_grupo                               NaN -0.032968
# percent_func_genero_masc                            NaN  0.146083
# percent_func_genero_fem                             NaN -0.146083
# idade_de_34_a_38                                    NaN -0.036330
# idade_de_39_a_43                                    NaN -0.169865
# idade_de_44_a_48                                    NaN -0.172429
# idade_de_49_a_53                                    NaN -0.141531
# grau_instrucao_macro_escolaridade_media             NaN -0.064018
# total                                               NaN -0.044948
# meses_ultima_contratacaco                           NaN -0.331042
# qt_admitidos_12meses                                NaN  0.268854
# qt_desligados_12meses                               NaN  0.190191
# qt_desligados                                       NaN  0.008521
# qt_admitidos                                        NaN -0.013623
# media_meses_servicos_all                            NaN -0.334306
# max_meses_servicos_all                              NaN -0.215623
# min_meses_servicos_all                              NaN -0.115209
# media_meses_servicos                                NaN -0.349415
# max_meses_servicos                                  NaN  0.066692
# min_meses_servicos                                  NaN -0.294905
# qt_funcionarios                                     NaN -0.044141
# qt_funcionarios_12meses                             NaN -0.057705
# qt_funcionarios_24meses                             NaN -0.069313
# tx_crescimento_12meses                              NaN  0.072407
# tx_rotatividade                                     NaN  0.282104
# qt_filiais                                          NaN  0.101688
#
#                                          fl_telefone  ...  \
# fl_matriz                                        NaN  ...
# idade_empresa_anos                         -0.495281  ...
# fl_me                                            NaN  ...
# fl_sa                                       0.028259  ...
# fl_epp                                           NaN  ...
# fl_mei                                           NaN  ...
# fl_ltda                                     0.061778  ...
# fl_st_especial                                   NaN  ...
# fl_email                                    0.686735  ...
# fl_telefone                                 1.000000  ...
# vl_total_veiculos_pesados_grupo             0.004261  ...
# vl_total_veiculos_leves_grupo               0.126171  ...
# vl_faturamento_estimado_aux                 0.039163  ...
# vl_faturamento_estimado_grupo_aux           0.035545  ...
# qt_ex_funcionarios                          0.088106  ...
# qt_funcionarios_grupo                      -0.096254  ...
# percent_func_genero_masc                    0.208441  ...
# percent_func_genero_fem                    -0.208441  ...
# idade_de_34_a_38                           -0.094813  ...
# idade_de_39_a_43                           -0.212961  ...
# idade_de_44_a_48                           -0.226136  ...
# idade_de_49_a_53                           -0.214031  ...
# grau_instrucao_macro_escolaridade_media    -0.087612  ...
# total                                      -0.100951  ...
# meses_ultima_contratacaco                  -0.379097  ...
# qt_admitidos_12meses                        0.176253  ...
# qt_desligados_12meses                       0.228808  ...
# qt_desligados                               0.088129  ...
# qt_admitidos                                0.020499  ...
# media_meses_servicos_all                   -0.364749  ...
# max_meses_servicos_all                     -0.256142  ...
# min_meses_servicos_all                     -0.061673  ...
# media_meses_servicos                       -0.405052  ...
# max_meses_servicos                          0.039422  ...
# min_meses_servicos                         -0.345566  ...
# qt_funcionarios                            -0.100101  ...
# qt_funcionarios_12meses                    -0.093661  ...
# qt_funcionarios_24meses                    -0.112386  ...
# tx_crescimento_12meses                      0.064698  ...
# tx_rotatividade                             0.304638  ...
# qt_filiais                                  0.089893  ...
#
#                                          min_meses_servicos_all  \
# fl_matriz                                                   NaN
# idade_empresa_anos                                     0.030244
# fl_me                                                       NaN
# fl_sa                                                 -0.025801
# fl_epp                                                      NaN
# fl_mei                                                      NaN
# fl_ltda                                               -0.011451
# fl_st_especial                                              NaN
# fl_email                                              -0.115209
# fl_telefone                                           -0.061673
# vl_total_veiculos_pesados_grupo                       -0.069783
# vl_total_veiculos_leves_grupo                         -0.074979
# vl_faturamento_estimado_aux                           -0.085704
# vl_faturamento_estimado_grupo_aux                     -0.088874
# qt_ex_funcionarios                                    -0.175940
# qt_funcionarios_grupo                                 -0.094726
# percent_func_genero_masc                              -0.187471
# percent_func_genero_fem                                0.187471
# idade_de_34_a_38                                      -0.108664
# idade_de_39_a_43                                      -0.046608
# idade_de_44_a_48                                      -0.054405
# idade_de_49_a_53                                      -0.052791
# grau_instrucao_macro_escolaridade_media               -0.060419
# total                                                 -0.089286
# meses_ultima_contratacaco                              0.493018
# qt_admitidos_12meses                                  -0.099360
# qt_desligados_12meses                                 -0.106364
# qt_desligados                                         -0.175907
# qt_admitidos                                          -0.171877
# media_meses_servicos_all                               0.304338
# max_meses_servicos_all                                 0.052240
# min_meses_servicos_all                                 1.000000
# media_meses_servicos                                   0.216415
# max_meses_servicos                                    -0.006054
# min_meses_servicos                                     0.450708
# qt_funcionarios                                       -0.089406
# qt_funcionarios_12meses                               -0.087567
# qt_funcionarios_24meses                               -0.116160
# tx_crescimento_12meses                                 0.012951
# tx_rotatividade                                       -0.136233
# qt_filiais                                            -0.035027
#
#                                          media_meses_servicos  \
# fl_matriz                                                 NaN
# idade_empresa_anos                                   0.536651
# fl_me                                                     NaN
# fl_sa                                                0.018896
# fl_epp                                                    NaN
# fl_mei                                                    NaN
# fl_ltda                                              0.012248
# fl_st_especial                                            NaN
# fl_email                                            -0.349415
# fl_telefone                                         -0.405052
# vl_total_veiculos_pesados_grupo                     -0.116985
# vl_total_veiculos_leves_grupo                        0.059946
# vl_faturamento_estimado_aux                          0.106075
# vl_faturamento_estimado_grupo_aux                    0.106901
# qt_ex_funcionarios                                  -0.244707
# qt_funcionarios_grupo                                0.047127
# percent_func_genero_masc                            -0.332182
# percent_func_genero_fem                              0.332182
# idade_de_34_a_38                                    -0.055625
# idade_de_39_a_43                                     0.088648
# idade_de_44_a_48                                     0.147968
# idade_de_49_a_53                                     0.250422
# grau_instrucao_macro_escolaridade_media             -0.032785
# total                                                0.060428
# meses_ultima_contratacaco                            0.628676
# qt_admitidos_12meses                                -0.471336
# qt_desligados_12meses                               -0.439230
# qt_desligados                                       -0.244866
# qt_admitidos                                        -0.156193
# media_meses_servicos_all                             0.837978
# max_meses_servicos_all                               0.474427
# min_meses_servicos_all                               0.216415
# media_meses_servicos                                 1.000000
# max_meses_servicos                                   0.123567
# min_meses_servicos                                   0.624979
# qt_funcionarios                                      0.058980
# qt_funcionarios_12meses                              0.070643
# qt_funcionarios_24meses                              0.065609
# tx_crescimento_12meses                              -0.111274
# tx_rotatividade                                     -0.647306
# qt_filiais                                          -0.095751
#
#                                          max_meses_servicos  \
# fl_matriz                                               NaN
# idade_empresa_anos                                 0.090446
# fl_me                                                   NaN
# fl_sa                                             -0.002315
# fl_epp                                                  NaN
# fl_mei                                                  NaN
# fl_ltda                                           -0.008892
# fl_st_especial                                          NaN
# fl_email                                           0.066692
# fl_telefone                                        0.039422
# vl_total_veiculos_pesados_grupo                   -0.061339
# vl_total_veiculos_leves_grupo                     -0.023945
# vl_faturamento_estimado_aux                        0.036967
# vl_faturamento_estimado_grupo_aux                  0.033175
# qt_ex_funcionarios                                 0.161675
# qt_funcionarios_grupo                              0.055423
# percent_func_genero_masc                          -0.084198
# percent_func_genero_fem                            0.084198
# idade_de_34_a_38                                   0.080345
# idade_de_39_a_43                                   0.048040
# idade_de_44_a_48                                   0.060054
# idade_de_49_a_53                                   0.038972
# grau_instrucao_macro_escolaridade_media            0.070203
# total                                              0.065820
# meses_ultima_contratacaco                          0.003372
# qt_admitidos_12meses                               0.022529
# qt_desligados_12meses                              0.065869
# qt_desligados                                      0.161757
# qt_admitidos                                       0.150913
# media_meses_servicos_all                           0.056275
# max_meses_servicos_all                             0.330939
# min_meses_servicos_all                            -0.006054
# media_meses_servicos                               0.123567
# max_meses_servicos                                 1.000000
# min_meses_servicos                                 0.000116
# qt_funcionarios                                    0.066453
# qt_funcionarios_12meses                            0.074418
# qt_funcionarios_24meses                            0.090350
# tx_crescimento_12meses                            -0.042703
# tx_rotatividade                                   -0.031300
# qt_filiais                                        -0.028252
#
#                                          min_meses_servicos  qt_funcionarios  \
# fl_matriz                                               NaN              NaN
# idade_empresa_anos                                 0.319070         0.145029
# fl_me                                                   NaN              NaN
# fl_sa                                             -0.023081         0.154004
# fl_epp                                                  NaN              NaN
# fl_mei                                                  NaN              NaN
# fl_ltda                                           -0.061009        -0.030746
# fl_st_especial                                          NaN              NaN
# fl_email                                          -0.294905        -0.044141
# fl_telefone                                       -0.345566        -0.100101
# vl_total_veiculos_pesados_grupo                   -0.117912         0.108140
# vl_total_veiculos_leves_grupo                     -0.032096         0.400804
# vl_faturamento_estimado_aux                        0.065435         0.729106
# vl_faturamento_estimado_grupo_aux                  0.037242         0.715026
# qt_ex_funcionarios                                -0.254050         0.350282
# qt_funcionarios_grupo                              0.036860         0.974509
# percent_func_genero_masc                          -0.275686        -0.094784
# percent_func_genero_fem                            0.275686         0.094784
# idade_de_34_a_38                                   0.077164         0.852744
# idade_de_39_a_43                                   0.187841         0.828470
# idade_de_44_a_48                                   0.184167         0.866962
# idade_de_49_a_53                                   0.168367         0.871803
# grau_instrucao_macro_escolaridade_media           -0.019421         0.834248
# total                                              0.080017         0.999989
# meses_ultima_contratacaco                          0.956677         0.093328
# qt_admitidos_12meses                              -0.392655         0.197027
# qt_desligados_12meses                             -0.400171         0.269394
# qt_desligados                                     -0.254102         0.350406
# qt_admitidos                                      -0.154103         0.714553
# media_meses_servicos_all                           0.576432         0.023939
# max_meses_servicos_all                             0.273954         0.202083
# min_meses_servicos_all                             0.450708        -0.089406
# media_meses_servicos                               0.624979         0.058980
# max_meses_servicos                                 0.000116         0.066453
# min_meses_servicos                                 1.000000         0.078829
# qt_funcionarios                                    0.078829         1.000000
# qt_funcionarios_12meses                            0.083146         0.994873
# qt_funcionarios_24meses                            0.058864         0.967215
# tx_crescimento_12meses                            -0.062602        -0.029724
# tx_rotatividade                                   -0.559092        -0.111825
# qt_filiais                                        -0.124076         0.120900
#
#                                          qt_funcionarios_12meses  \
# fl_matriz                                                    NaN
# idade_empresa_anos                                      0.156250
# fl_me                                                        NaN
# fl_sa                                                   0.153452
# fl_epp                                                       NaN
# fl_mei                                                       NaN
# fl_ltda                                                -0.029594
# fl_st_especial                                               NaN
# fl_email                                               -0.057705
# fl_telefone                                            -0.093661
# vl_total_veiculos_pesados_grupo                         0.104474
# vl_total_veiculos_leves_grupo                           0.393737
# vl_faturamento_estimado_aux                             0.722648
# vl_faturamento_estimado_grupo_aux                       0.708234
# qt_ex_funcionarios                                      0.369450
# qt_funcionarios_grupo                                   0.968618
# percent_func_genero_masc                               -0.099858
# percent_func_genero_fem                                 0.099858
# idade_de_34_a_38                                        0.849486
# idade_de_39_a_43                                        0.827920
# idade_de_44_a_48                                        0.867492
# idade_de_49_a_53                                        0.871090
# grau_instrucao_macro_escolaridade_media                 0.823744
# total                                                   0.994872
# meses_ultima_contratacaco                               0.097599
# qt_admitidos_12meses                                    0.144530
# qt_desligados_12meses                                   0.287023
# qt_desligados                                           0.369560
# qt_admitidos                                            0.726538
# media_meses_servicos_all                                0.032183
# max_meses_servicos_all                                  0.209479
# min_meses_servicos_all                                 -0.087567
# media_meses_servicos                                    0.070643
# max_meses_servicos                                      0.074418
# min_meses_servicos                                      0.083146
# qt_funcionarios                                         0.994873
# qt_funcionarios_12meses                                 1.000000
# qt_funcionarios_24meses                                 0.968894
# tx_crescimento_12meses                                 -0.061524
# tx_rotatividade                                        -0.113283
# qt_filiais                                              0.116996
#
#                                          qt_funcionarios_24meses  \
# fl_matriz                                                    NaN
# idade_empresa_anos                                      0.176955
# fl_me                                                        NaN
# fl_sa                                                   0.146374
# fl_epp                                                       NaN
# fl_mei                                                       NaN
# fl_ltda                                                -0.029959
# fl_st_especial                                               NaN
# fl_email                                               -0.069313
# fl_telefone                                            -0.112386
# vl_total_veiculos_pesados_grupo                         0.110381
# vl_total_veiculos_leves_grupo                           0.378238
# vl_faturamento_estimado_aux                             0.683715
# vl_faturamento_estimado_grupo_aux                       0.673034
# qt_ex_funcionarios                                      0.496046
# qt_funcionarios_grupo                                   0.950297
# percent_func_genero_masc                               -0.071515
# percent_func_genero_fem                                 0.071515
# idade_de_34_a_38                                        0.819522
# idade_de_39_a_43                                        0.798120
# idade_de_44_a_48                                        0.833543
# idade_de_49_a_53                                        0.841945
# grau_instrucao_macro_escolaridade_media                 0.817514
# total                                                   0.967052
# meses_ultima_contratacaco                               0.069366
# qt_admitidos_12meses                                    0.171470
# qt_desligados_12meses                                   0.283552
# qt_desligados                                           0.496149
# qt_admitidos                                            0.808568
# media_meses_servicos_all                                0.003603
# max_meses_servicos_all                                  0.210602
# min_meses_servicos_all                                 -0.116160
# media_meses_servicos                                    0.065609
# max_meses_servicos                                      0.090350
# min_meses_servicos                                      0.058864
# qt_funcionarios                                         0.967215
# qt_funcionarios_12meses                                 0.968894
# qt_funcionarios_24meses                                 1.000000
# tx_crescimento_12meses                                 -0.061869
# tx_rotatividade                                        -0.108707
# qt_filiais                                              0.108947
#
#                                          tx_crescimento_12meses  \
# fl_matriz                                                   NaN
# idade_empresa_anos                                    -0.123002
# fl_me                                                       NaN
# fl_sa                                                 -0.009264
# fl_epp                                                      NaN
# fl_mei                                                      NaN
# fl_ltda                                               -0.004254
# fl_st_especial                                              NaN
# fl_email                                               0.072407
# fl_telefone                                            0.064698
# vl_total_veiculos_pesados_grupo                       -0.019612
# vl_total_veiculos_leves_grupo                         -0.018643
# vl_faturamento_estimado_aux                            0.005493
# vl_faturamento_estimado_grupo_aux                      0.014796
# qt_ex_funcionarios                                    -0.035812
# qt_funcionarios_grupo                                 -0.018490
# percent_func_genero_masc                              -0.024715
# percent_func_genero_fem                                0.024715
# idade_de_34_a_38                                      -0.024476
# idade_de_39_a_43                                      -0.039983
# idade_de_44_a_48                                      -0.039301
# idade_de_49_a_53                                      -0.031727
# grau_instrucao_macro_escolaridade_media               -0.043525
# total                                                 -0.029769
# meses_ultima_contratacaco                             -0.064051
# qt_admitidos_12meses                                   0.202800
# qt_desligados_12meses                                 -0.019354
# qt_desligados                                         -0.035817
# qt_admitidos                                          -0.040213
# media_meses_servicos_all                              -0.081581
# max_meses_servicos_all                                -0.060840
# min_meses_servicos_all                                 0.012951
# media_meses_servicos                                  -0.111274
# max_meses_servicos                                    -0.042703
# min_meses_servicos                                    -0.062602
# qt_funcionarios                                       -0.029724
# qt_funcionarios_12meses                               -0.061524
# qt_funcionarios_24meses                               -0.061869
# tx_crescimento_12meses                                 1.000000
# tx_rotatividade                                       -0.025800
# qt_filiais                                             0.001877
#
#                                          tx_rotatividade  qt_filiais
# fl_matriz                                            NaN         NaN
# idade_empresa_anos                             -0.424699    0.064457
# fl_me                                                NaN         NaN
# fl_sa                                          -0.032606    0.088444
# fl_epp                                               NaN         NaN
# fl_mei                                               NaN         NaN
# fl_ltda                                         0.002202   -0.013117
# fl_st_especial                                       NaN         NaN
# fl_email                                        0.282104    0.101688
# fl_telefone                                     0.304638    0.089893
# vl_total_veiculos_pesados_grupo                 0.062409    0.102501
# vl_total_veiculos_leves_grupo                  -0.089044    0.211646
# vl_faturamento_estimado_aux                    -0.139905    0.137892
# vl_faturamento_estimado_grupo_aux              -0.130863    0.188412
# qt_ex_funcionarios                              0.301718    0.052219
# qt_funcionarios_grupo                          -0.092976    0.146274
# percent_func_genero_masc                        0.350656   -0.059361
# percent_func_genero_fem                        -0.350656    0.059361
# idade_de_34_a_38                               -0.063225    0.025180
# idade_de_39_a_43                               -0.154984    0.011454
# idade_de_44_a_48                               -0.186243    0.064305
# idade_de_49_a_53                               -0.223065    0.120502
# grau_instrucao_macro_escolaridade_media         0.000266    0.070985
# total                                          -0.113326    0.120901
# meses_ultima_contratacaco                      -0.575170   -0.123176
# qt_admitidos_12meses                            0.559973    0.048857
# qt_desligados_12meses                           0.626897    0.042158
# qt_desligados                                   0.301944    0.052269
# qt_admitidos                                    0.174897    0.093788
# media_meses_servicos_all                       -0.526251   -0.099308
# max_meses_servicos_all                         -0.290915   -0.103392
# min_meses_servicos_all                         -0.136233   -0.035027
# media_meses_servicos                           -0.647306   -0.095751
# max_meses_servicos                             -0.031300   -0.028252
# min_meses_servicos                             -0.559092   -0.124076
# qt_funcionarios                                -0.111825    0.120900
# qt_funcionarios_12meses                        -0.113283    0.116996
# qt_funcionarios_24meses                        -0.108707    0.108947
# tx_crescimento_12meses                         -0.025800    0.001877
# tx_rotatividade                                 1.000000    0.045069
# qt_filiais                                      0.045069    1.000000
#
# [41 rows x 41 columns]

# %%
cor_market_portfolio_3_T2 = portfolio_3_T2.drop(['fl_matriz','setor','fl_me', 'fl_epp', 'fl_mei', 'fl_st_especial', 'fl_passivel_iss'], axis = 1)
correlation = cor_market_portfolio_3_T2.corr(method="pearson")
f, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(correlation, center=True, square=True, annot=True, cmap="gist_gray",fmt='.2f', 
                 annot_kws={'size': 5});

# %% [markdown]
# >> ### Overview about Company 3's clients:

# %% [markdown]
# - Customers provide at least 63 data (already counting with the id);
# - Companies of any age, even if less than 1 year old. But most are over 20;
# - All customers, without exception are from the service sector;
# - Have revenues over 10 million;
# - Varied legal nature, but most are municipalities, companies and public agencies;
# - Various branches but the main one is public administration, defense and social security;
# - The data: fl_matriz, fl_passivel_iss always have value “True”;
# - The data: fl_me, fl_mei, fl_epp, fl_st_especial always have value “False”;

# %% [markdown]
# ***
